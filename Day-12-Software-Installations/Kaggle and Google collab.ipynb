# %% [markdown]
# # How to work on Kaggle

# %% [markdown]
# Go to kaggle -> search data set -> click data set -> Click on new notebook
#
# new book created same as jupyter notebook

# %% [markdown]
# # Google Collab

# %% [markdown]
# - Linked with google drive, code automattically saved in drive
# - GPU power, if you dont have high gpu machine u can use this
#
# runtime setting -> change runtime type -> GPU
# in this way you can select hardware gpu -> Fast run in deep learning
