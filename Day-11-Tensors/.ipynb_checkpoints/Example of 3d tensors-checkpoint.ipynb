# %% [markdown]
# # Example of 3D tensors

# %%
import numpy as np

# %%
# ML models is pure mathematics, it did not understand text.

# %% [markdown]
# ![image.png](attachment:1386ce9f-6a10-4883-8472-caf2c1b3914c.png)

# %%
c = np.array([
    [[4,4,5,7,5],[64,4,3,5,4],[34,35,6,4,6]],
     [[4,4,5,7,5],[64,4,3,5,4],[34,35,6,4,6]],
     [[4,4,5,7,5],[64,4,3,5,4],[34,35,6,4,6]]
])
c
# Out:
# array([[[ 4,  4,  5,  7,  5],
#         [64,  4,  3,  5,  4],
#         [34, 35,  6,  4,  6]],
#
#        [[ 4,  4,  5,  7,  5],
#         [64,  4,  3,  5,  4],
#         [34, 35,  6,  4,  6]],
#
#        [[ 4,  4,  5,  7,  5],
#         [64,  4,  3,  5,  4],
#         [34, 35,  6,  4,  6]]])

# %%
c.ndim
# Out:
# 3

# %%
# Time series data is always a 3D data

# Medical and finance data is mostly a time series data
