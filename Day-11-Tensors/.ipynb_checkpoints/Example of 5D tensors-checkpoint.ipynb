# %% [markdown]
# # Example of 5D tensors

# %%
# Videos are the best example of 5D tensors.

# Its a collection of many images or 4D tensors

# %% [markdown]
# ![image.png](attachment:ae11c431-c31c-44df-82f9-85b93d3b1edf.png)
