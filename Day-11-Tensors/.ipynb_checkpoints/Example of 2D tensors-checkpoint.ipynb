# %% [markdown]
# # Example of 2D tensors
# - Collection of 1 D tensors
# - should be stored in a matrics

# %%
import numpy as np

# %%
a = np.array([
    [4,4,5,7,5],[64,4,3,5,4]
])

# %%
a
# Out:
# array([[ 4,  4,  5,  7,  5],
#        [64,  4,  3,  5,  4]])

# %%
a.ndim
# Out:
# 2
