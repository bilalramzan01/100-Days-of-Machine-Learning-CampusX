# %% [markdown]
# # Example of 1D tensor

# %%
import numpy as np

# %%
a = np.array([4,4,5])

# %%
a
# Out:
# array([4, 4, 5])

# %%
a.ndim
# Out:
# 1

# %%
# This is 1 dimension tensor because it have only 
# But it is three dim vector because it have three features or input ba
