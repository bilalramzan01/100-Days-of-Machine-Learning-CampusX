# %% [markdown]
# # Tensors

# %% [markdown]
# ## 0D Tensors / Scalars / 0D Array

# %%
import numpy as np

# %%
a = np.array(4)

# %%
# Scalar or 0 dimension array or tensor
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
## 1D tensors / Tensors / 1D array / Vecto

# %%
a = np.array([4,4,5,7,5])
a
# Out:
# array([4, 4, 5, 7, 5])

# %%
a.ndim
# Out:
# 1

# %%
## No of axis = Rank = dim of tensors
