# %% [markdown]
# # Example of 4D tensors

# %%
# Image processing

# Image is in the form of pixels , and every pixel holds numerical value thats why can see on the image.

# By controlling the pixels we can see the image

# %% [markdown]
# ![image.png](attachment:9aba128b-21fe-469a-97b3-c6cd5498b2ef.png)
