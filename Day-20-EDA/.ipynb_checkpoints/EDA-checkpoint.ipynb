# %% [markdown]
# ## EDA (Exploratry data analysis
#
# 1. Uni variate analysis
# 2. Bi-variate analysis
# 3. multi-variate analysis

# %% [markdown]
# ## Data types
#
# 1. Numerical data (Height, weight, age, phone no)
# 2. Categorical data ( Nationality, State, Gender, Company)

# %% [markdown]
# ## Uni-variate analysis
#
# - first of all we will check weather the data is numerical or categorical

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Start analysis from left to right
# Here we are going to start from categorical data

# %%
df.shape
# Out:
# (891, 12)

# %%
df['Survived'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
print(df['Survived'].unique())
# Out:
# [0 1]
