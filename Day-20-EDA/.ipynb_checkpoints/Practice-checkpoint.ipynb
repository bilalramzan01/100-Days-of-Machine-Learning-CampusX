# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('asiacup.csv')

# %%
df.head(5)
# Out:
#         Team   Opponent Format   Ground  Year  Toss Selection  Run Scored  \
# 0   Pakistan  Sri Lanka    ODI  Sharjah  1984  Lose   Batting       187.0
# 1  Sri Lanka   Pakistan    ODI  Sharjah  1984   Win   Bowling       190.0
# 2      India  Sri Lanka    ODI  Sharjah  1984   Win   Bowling        97.0
# 3  Sri Lanka      India    ODI  Sharjah  1984  Lose   Batting        96.0
# 4      India   Pakistan    ODI  Sharjah  1984   Win   Batting       188.0
#
#    Wicket Lost  Fours  Sixes  Extras  Run Rate  Avg Bat Strike Rate  \
# 0          9.0    9.0    3.0    21.0      4.06                52.04
# 1          5.0   11.0    1.0    26.0      4.36                68.51
# 2          0.0    9.0    0.0    14.0      4.47                60.48
# 3         10.0    7.0    0.0     8.0      2.34                25.74
# 4          4.0   13.0    3.0    17.0      4.08                60.21
#
#    Highest Score  Wicket Taken  Given Extras  Highest Individual wicket  \
# ...

# %%
df.shape
# Out:
# (254, 20)

# %%
df.sample(5)
# Out:
#           Team    Opponent Format        Ground  Year  Toss Selection  \
# 133      India  Bangladesh    ODI      Dambulla  2010  Lose   Bowling
# 6    Sri Lanka    Pakistan    ODI  Colombo(PSS)  1986   Win   Bowling
# 151      India  Bangladesh    ODI        Mirpur  2012  Lose   Batting
# 251  Sri Lanka    Pakistan   T20I    Dubai(DSC)  2022   Win   Bowling
# 227      India  Bangladesh    ODI    Dubai(DSC)  2018   Win   Bowling
#
#      Run Scored  Wicket Lost  Fours  Sixes  Extras  Run Rate  \
# 133       168.0          4.0   11.0    1.0    25.0      5.47
# 6         116.0         10.0   10.0    0.0    14.0      3.42
# 151       289.0          5.0   25.0    3.0    18.0      5.78
# 251       124.0          5.0    9.0    5.0     5.0      7.29
# 227       223.0          7.0   13.0    6.0    13.0      4.46
#
#      Avg Bat Strike Rate  Highest Score  Wicket Taken  Given Extras  \
# 133                65.70           82.0          10.0          21.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Team                       254 non-null    object
#  1   Opponent                   254 non-null    object
#  2   Format                     254 non-null    object
#  3   Ground                     254 non-null    object
#  4   Year                       254 non-null    int64
#  5   Toss                       254 non-null    object
#  6   Selection                  254 non-null    object
#  7   Run Scored                 252 non-null    float64
#  8   Wicket Lost                252 non-null    float64
#  9   Fours                      252 non-null    float64
#  10  Sixes                      252 non-null    float64
#  11  Extras                     252 non-null    float64
#  12  Run Rate                   252 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Team                         0
# Opponent                     0
# Format                       0
# Ground                       0
# Year                         0
# Toss                         0
# Selection                    0
# Run Scored                   2
# Wicket Lost                  2
# Fours                        2
# Sixes                        2
# Extras                       2
# Run Rate                     2
# Avg Bat Strike Rate          2
# Highest Score                2
# Wicket Taken                 2
# Given Extras                 2
# Highest Individual wicket    2
# Player Of The Match          2
# Result                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               Year  Run Scored  Wicket Lost       Fours       Sixes  \
# count   254.000000  252.000000   252.000000  252.000000  252.000000
# mean   2006.905512  201.920635     6.892857   15.626984    2.912698
# std      11.014495   67.331860     2.874609    7.754946    2.596411
# min    1984.000000   38.000000     0.000000    0.000000    0.000000
# 25%    1997.750000  147.000000     5.000000   10.000000    1.000000
# 50%    2008.000000  193.000000     7.000000   15.000000    2.000000
# 75%    2016.000000  253.250000    10.000000   20.000000    4.250000
# max    2022.000000  385.000000    10.000000   41.000000   14.000000
#
#            Extras    Run Rate  Avg Bat Strike Rate  Highest Score  \
# count  252.000000  252.000000           252.000000     252.000000
# mean    13.238095    5.308214            76.676667      69.309524
# std      7.621973    1.584823            30.678228      29.813488
# min      0.000000    2.200000            24.630000       8.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                Year  Run Scored  Wicket Lost     Fours  \
# Year                       1.000000    0.014009     0.038296  0.232972
# Run Scored                 0.014009    1.000000    -0.070462  0.784983
# Wicket Lost                0.038296   -0.070462     1.000000 -0.167114
# Fours                      0.232972    0.784983    -0.167114  1.000000
# Sixes                      0.443333    0.399230    -0.225452  0.339302
# Extras                    -0.363250    0.212476     0.172822  0.022201
# Run Rate                   0.503914    0.239117    -0.448030  0.359799
# Avg Bat Strike Rate        0.382868    0.366079    -0.525216  0.450348
# Highest Score              0.054595    0.758422    -0.283882  0.646752
# Wicket Taken               0.038296    0.207894    -0.251141  0.210517
# Given Extras              -0.363250    0.247573    -0.024652  0.191046
# Highest Individual wicket  0.067085    0.183361    -0.152116  0.192786
#
# ...

# %%
df['Result_encoded'] = df['Result'].map({'Win': 1, 'Lose': 0})

# %%
df['Result_encoded'].value_counts()
# Out:
# Result_encoded
# 0.0    124
# 1.0    123
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)['Result_encoded']
# Out:
# Year                         0.007723
# Run Scored                   0.288634
# Wicket Lost                 -0.598237
# Fours                        0.311732
# Sixes                        0.244690
# Extras                      -0.084062
# Run Rate                     0.399552
# Avg Bat Strike Rate          0.449137
# Highest Score                0.356909
# Wicket Taken                 0.600094
# Given Extras                 0.082682
# Highest Individual wicket    0.440975
# Result_encoded               1.000000
# Name: Result_encoded, dtype: float64

# %%
df['Year'].value_counts().plot(kind="pie" , autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.hist(['Year'], bins=2)
# Out:
# array([[<Axes: title={'center': 'Year'}>]], dtype=object)

# %%
df['Sixes'].min()
# Out:
# 0.0

# %%
df['Sixes'].max()
# Out:
# 14.0

# %%
df['Sixes'].mean()
# Out:
# np.float64(2.9126984126984126)
