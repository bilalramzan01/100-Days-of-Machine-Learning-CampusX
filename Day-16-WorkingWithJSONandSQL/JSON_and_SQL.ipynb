# %% [markdown]
# # Working with JSON
# JSON (JavaScript Object Notation) is a lightweight, text-based data format used to store and exchange structured data — it's the most common format for sending data between servers, APIs, and applications on the web.

# %%
import pandas as pd

# %%
df = pd.read_json("train.json")

# %%
df
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # Working with SQL
#
# **SQL (Structured Query Language)** is the standard language used to communicate with relational databases — used to create, read, update, and delete data stored in structured tables (rows and columns).
#
# **Core idea**
#
# Data in SQL databases is organized into tables (like spreadsheets), where each table has columns (fields) and rows (records). SQL is how you query, filter, join, and manipulate this data.

# %%
# Need library
# !pip install mysql.connector
import mysql.connector
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\bilal\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\bilal\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\bilal\anaconda3\Lib\site-packages)

# %%
# Create connection between data base

con = mysql.connector.connect(host="localhost",user='root',password='',database='world')
con

# %%
pd.read_sql_query("SELECT * FROM city", con)
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_8592\4158175699.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city", con)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PAK'", con)
# Out:
# C:\Users\bilal\AppData\Local\Temp\ipykernel_8592\3390971073.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'PAK'", con)
#       ID              Name CountryCode              District  Population
# 0   2822           Karachi         PAK                 Sindh     9269265
# 1   2823            Lahore         PAK                Punjab     5063499
# 2   2824        Faisalabad         PAK                Punjab     1977246
# 3   2825        Rawalpindi         PAK                Punjab     1406214
# 4   2826            Multan         PAK                Punjab     1182441
# 5   2827         Hyderabad         PAK                 Sindh     1151274
# 6   2828        Gujranwala         PAK                Punjab     1124749
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'USA'", con)
