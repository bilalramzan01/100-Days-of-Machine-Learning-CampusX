# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\bilal\anaconda3\lib\site-packages (2.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\bilal\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bilal\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\bilal\anaconda3\lib\site-packages (from beautifulsoup4) (4.16.0)

# %% [markdown]
# ## Vertex Networking Scraper (v5)
#
# Columns: `category, title, description, image, price, part_number, url`
#
# - **title**: derived from the description text (their on-page `<h1>` gets truncated by their template)
# - **price**: if a product has no price and shows a "Request A Quote" button instead, the price cell will say `Get a Quote for price`
# - **part_number**: pulled from the "Part Number: XXXXX" line on each product page
# - **image**: checks multiple lazy-load attributes, not just `src`, since their real photo may not be in the plain `src`
#
# **Run the cell below first** to clear out any old CSV from earlier versions — otherwise the resume logic will skip those URLs and keep the old bad data.

# %%
#!/usr/bin/env python3
"""
Scraper for vertexnetworking.co.uk
Walks every category -> subcategory -> product listing (with pagination),
visits each product page, and writes:
    category, title, description, image, price, part_number, url
to a CSV file INCREMENTALLY (row-by-row) so no progress is lost if it's
interrupted or crashes partway through.

Field notes (learned from inspecting a real product page):
- title: their on-page <h1> is truncated by their template, so the title
  is instead derived from the Description text (which contains the full,
  untruncated name before "Product Condition:").
- price: some products don't have a price at all and instead show a
  "Request A Quote" / "Get A Quote" button. For those, the price cell is
  written as "Get a Quote for price" instead of being left blank or $0.00.
- part_number: pulled from the "Part Number: XXXXX" line on the page.
- image: their real product photo may be lazy-loaded (data-src / srcset
  instead of a plain src), so several attributes are checked.

Requirements:
    pip install requests beautifulsoup4

Usage:
    python scrape_vertexnetworking.py

Output:
    vertexnetworking_products.csv   (written to as it goes)

If you stop the script and run it again later, it will skip any product
URLs already present in the CSV, so it resumes instead of starting over.
Delete the CSV first if you want a completely fresh run.
"""

import csv
import os
import time
import re
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup

BASE_URL = "https://www.vertexnetworking.co.uk"
OUTPUT_CSV = "vertexnetworking_products.csv"
REQUEST_DELAY = 0.75   # seconds between requests, be polite to their server
TIMEOUT = 20
PROGRESS_EVERY = 25    # print a running total every N products scraped

FIELDNAMES = ["category", "title", "description", "image", "price", "part_number", "url"]

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    )
}

GENERIC_HEADINGS = {"vertex networking", "home", "products", "detail"}
QUOTE_TEXT_PATTERN = re.compile(r"request\s*a?\s*quote|get\s*a?\s*quote", re.I)

session = requests.Session()
session.headers.update(HEADERS)


def get_soup(url):
    """Fetch a URL and return a BeautifulSoup object, or None on failure."""
    try:
        resp = session.get(url, timeout=TIMEOUT)
        resp.raise_for_status()
        time.sleep(REQUEST_DELAY)
        return BeautifulSoup(resp.text, "html.parser")
    except requests.RequestException as e:
        print(f"  [warn] failed to fetch {url}: {e}")
        return None


def discover_category_links():
    """Find every /category/N and /subcategory/N link from the homepage nav."""
    soup = get_soup(BASE_URL)
    if soup is None:
        raise SystemExit("Could not load homepage — aborting.")

    links = set()
    for a in soup.find_all("a", href=True):
        href = a["href"]
        full = urljoin(BASE_URL, href)
        if re.search(r"/(category|subcategory)/\d+", full):
            links.add(full)
    return sorted(links)


def get_category_label(soup, fallback_url):
    """Try to pull a readable category/subcategory name from a listing page."""
    h1 = soup.find("h1")
    if h1 and h1.get_text(strip=True):
        return h1.get_text(strip=True)
    title = soup.find("title")
    if title and title.get_text(strip=True):
        return title.get_text(strip=True).split("|")[0].strip()
    return fallback_url


def find_product_links(soup):
    """Extract all product detail page links from a listing page."""
    links = set()
    for a in soup.find_all("a", href=True):
        href = urljoin(BASE_URL, a["href"])
        if "/product/" in href and href.endswith(".html"):
            links.add(href)
    return links


def find_next_page(soup, current_url):
    """Look for a 'next page' pagination link."""
    next_link = soup.find("a", rel="next")
    if next_link and next_link.get("href"):
        return urljoin(current_url, next_link["href"])

    for a in soup.find_all("a", href=True):
        text = a.get_text(strip=True).lower()
        if text in ("next", "»", "next »", ">"):
            return urljoin(current_url, a["href"])

    return None


def clean_description_text(text):
    """Strip repeated 'Description' / 'Product Description' header words that
    get scooped up when we grab the whole section's text."""
    text = re.sub(r"^\s*(Description\s*)+", "", text, flags=re.I)
    text = re.sub(r"^\s*(Product Description\s*)+", "", text, flags=re.I)
    return text.strip()


def is_nonzero_price(text):
    digits = re.sub(r"[^\d.]", "", text)
    try:
        return float(digits) > 0
    except (ValueError, TypeError):
        return False


def extract_description(soup):
    desc_section = soup.find(["div", "section"], id=re.compile(r"description", re.I))
    if not desc_section:
        desc_section = soup.find(
            ["div", "section"],
            class_=re.compile(r"(product-desc|description|details)", re.I),
        )
    if desc_section:
        text = clean_description_text(desc_section.get_text(" ", strip=True))
        if text:
            return text

    meta_desc = soup.find("meta", attrs={"name": "description"})
    if meta_desc and meta_desc.get("content"):
        return meta_desc["content"].strip()
    return None


def extract_title(soup, description):
    # Priority 1: derive from the description — it reliably starts with
    # "PARTNUMBER - Brand ... Product Name" followed by "Product Condition:",
    # and is more complete than their on-page <h1> (which gets truncated).
    if description:
        parts = re.split(r"Product Condition\s*:", description, flags=re.I)
        candidate = parts[0].strip(" -")
        if candidate and len(candidate) > 3:
            return candidate

    # Priority 2: a real <h1>/<h2> that isn't the generic site header.
    for h in soup.find_all(["h1", "h2"]):
        text = h.get_text(strip=True)
        if text and text.lower() not in GENERIC_HEADINGS and len(text) > 3:
            return text

    # Priority 3: meta/og:title as an absolute last resort.
    og_title = soup.find("meta", property="og:title")
    if og_title and og_title.get("content"):
        return og_title["content"].strip()
    return None


def extract_image(soup):
    """Their real product photo may be lazy-loaded, so check several
    possible attributes, not just src. Real product images tend to come
    LATER in the page than banner/logo images, so prefer the last match."""
    candidates = []
    for img in soup.find_all("img"):
        for attr in ("src", "data-src", "data-original", "data-lazy-src", "data-image"):
            val = img.get(attr)
            if val and "/product_images/" in val:
                candidates.append(urljoin(BASE_URL, val))
                break
        else:
            srcset = img.get("srcset")
            if srcset and "/product_images/" in srcset:
                first_url = srcset.split(",")[0].strip().split(" ")[0]
                candidates.append(urljoin(BASE_URL, first_url))

    if candidates:
        return candidates[-1]

    og_image = soup.find("meta", property="og:image")
    if og_image and og_image.get("content"):
        return urljoin(BASE_URL, og_image["content"].strip())
    return None


def extract_price(soup):
    # 1. class="...price..." element with a non-zero value
    for tag in soup.find_all(["span", "div", "p"], class_=re.compile(r"price", re.I)):
        m = re.search(r"[\$£€]\s?[\d,]+\.?\d*", tag.get_text(" ", strip=True))
        if m and is_nonzero_price(m.group(0)):
            return m.group(0).strip()

    # 2. price-looking data embedded in <script> tags
    for script in soup.find_all("script"):
        if not script.string:
            continue
        m = re.search(r'"price"\s*:\s*"?\$?£?€?\s?([\d]+\.?\d*)"?', script.string)
        if m and is_nonzero_price(m.group(1)):
            return f"${m.group(1)}"

    # 3. any non-zero currency-looking value anywhere on the page
    #    (skips things like the header's "Shopping Cart: $0.00")
    for m in re.finditer(r"[\$£€]\s?[\d,]+\.\d{2}", soup.get_text(" ", strip=True)):
        if is_nonzero_price(m.group(0)):
            return m.group(0).strip()

    # 4. No price found at all — check if this is a "request a quote" item
    if soup.find(string=QUOTE_TEXT_PATTERN):
        return "Get a Quote for price"

    return None


def extract_part_number(soup):
    text = soup.get_text(" ", strip=True)
    m = re.search(r"Part\s*Number\s*:?\s*([A-Za-z0-9][A-Za-z0-9\-\/\.]*)", text, re.I)
    if m:
        return m.group(1).strip()
    return None


def scrape_product(url, category_label):
    """Visit a product page and extract all fields."""
    soup = get_soup(url)
    if soup is None:
        return None

    description = extract_description(soup)
    title = extract_title(soup, description)
    image = extract_image(soup)
    price = extract_price(soup)
    part_number = extract_part_number(soup)

    return {
        "category": category_label,
        "title": title or "",
        "description": description or "",
        "image": image or "",
        "price": price or "",
        "part_number": part_number or "",
        "url": url,
    }


def load_already_scraped():
    """If the CSV already exists (from a previous run), load which product
    URLs are already done so we can skip them and resume."""
    done = set()
    if os.path.exists(OUTPUT_CSV):
        with open(OUTPUT_CSV, "r", newline="", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            for row in reader:
                if row.get("url"):
                    done.add(row["url"])
    return done


def open_csv_writer():
    """Open the CSV in append mode, writing the header only if new."""
    file_exists = os.path.exists(OUTPUT_CSV)
    f = open(OUTPUT_CSV, "a", newline="", encoding="utf-8")
    writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
    if not file_exists:
        writer.writeheader()
        f.flush()
    return f, writer


def main():
    already_done = load_already_scraped()
    if already_done:
        print(f"Resuming — {len(already_done)} products already in {OUTPUT_CSV}, will skip those.")

    csv_file, writer = open_csv_writer()
    scraped_count = len(already_done)

    try:
        print("Discovering category/subcategory links...")
        category_links = discover_category_links()
        print(f"Found {len(category_links)} category/subcategory links.")

        for cat_index, cat_url in enumerate(category_links, start=1):
            print(f"\n[{cat_index}/{len(category_links)}] Category page: {cat_url}")
            page_url = cat_url
            visited_pages = set()

            while page_url and page_url not in visited_pages:
                visited_pages.add(page_url)
                soup = get_soup(page_url)
                if soup is None:
                    break

                label = get_category_label(soup, cat_url)
                product_links = find_product_links(soup)
                new_links = [p for p in product_links if p not in already_done]
                print(f"  {page_url} -> {len(product_links)} product links "
                      f"({len(new_links)} new)")

                for p_url in new_links:
                    row = scrape_product(p_url, label)
                    already_done.add(p_url)
                    if row:
                        writer.writerow(row)
                        csv_file.flush()  # write to disk immediately
                        scraped_count += 1
                        if scraped_count % PROGRESS_EVERY == 0:
                            print(f"  >>> progress: {scraped_count} products saved so far")

                page_url = find_next_page(soup, page_url)

    except KeyboardInterrupt:
        print("\n[stopped by user] Progress so far is safely saved in the CSV.")
    finally:
        csv_file.close()

    print(f"\nTotal products in {OUTPUT_CSV}: {scraped_count}")
    print("Done (or safely stopped — rerun the script anytime to resume).")


if __name__ == "__main__":
    main()
# Out:
# Resuming — 5063 products already in vertexnetworking_products.csv, will skip those.
# Discovering category/subcategory links...
# Found 120 category/subcategory links.
#
# [1/120] Category page: https://www.vertexnetworking.co.uk/category/1
#   https://www.vertexnetworking.co.uk/category/1 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=2 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=3 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=4 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=5 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=6 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=7 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=8 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=9 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=10 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=11 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=12 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=13 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=14 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=15 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=16 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=17 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=18 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=19 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=20 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=21 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=22 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=23 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=24 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=25 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=26 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=27 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=28 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=29 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=30 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=31 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=32 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=33 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=34 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=35 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=36 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=37 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=38 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=39 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=40 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=41 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=42 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=43 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=44 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=45 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=46 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=47 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=48 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=49 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=50 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=51 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=52 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=53 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=54 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=55 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=56 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=57 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=58 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=59 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=60 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=61 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=62 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=63 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=64 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=65 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=66 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=67 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=68 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=69 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=70 -> 20 product links (1 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/q2133a-hp-dvd-420i-dvd%3F%3Frw-optical-drive.html: 403 Client Error: Forbidden for url: https://www.vertexnetworking.co.uk/product/q2133a-hp-dvd-420i-dvd%3F%3Frw-optical-drive.html
#   https://www.vertexnetworking.co.uk/category/1?page=71 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=72 -> 20 product links (1 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/ca06123-b331-fujitsu-mcm3130ap-magneto-optical-disk-drive-1-3gb-2048-bps-40-pin-idc-ultra-ata-33-ata-4-ide-eide-4%22-internal.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/ca06123-b331-fujitsu-mcm3130ap-magneto-optical-disk-drive-1-3gb-2048-bps-40-pin-idc-ultra-ata-33-ata-4-ide-eide-4%22-internal.html
#   https://www.vertexnetworking.co.uk/category/1?page=73 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=74 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=75 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=76 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=77 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=78 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=79 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=80 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=81 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=82 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=83 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=84 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=85 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=86 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=87 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=88 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=89 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=90 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=91 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=92 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=93 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=94 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=95 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=96 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=97 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=98 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=99 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=100 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=101 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=102 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=103 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=104 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=105 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=106 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=107 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=108 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=109 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=110 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=111 -> 20 product links (1 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/43w8467-lenovo-16x-half-height-sata-multi-burner-dvd%C3%82%C2%B1rw-optical-drives.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/43w8467-lenovo-16x-half-height-sata-multi-burner-dvd%C3%82%C2%B1rw-optical-drives.html
#   https://www.vertexnetworking.co.uk/category/1?page=112 -> 20 product links (1 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/45k0432-lenovo-ideacentre-a720-aio-27%22-desktop-bd-rom-dvd-rewriter-optical-drive.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/45k0432-lenovo-ideacentre-a720-aio-27%22-desktop-bd-rom-dvd-rewriter-optical-drive.html
#   https://www.vertexnetworking.co.uk/category/1?page=113 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=114 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=115 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=116 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=117 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=118 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=119 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=120 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=121 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=122 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=123 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=124 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=125 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=126 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=127 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=128 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=129 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=130 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=131 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=132 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=133 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=134 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=135 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=136 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=137 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=138 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=139 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=140 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=141 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=142 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=143 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=144 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=145 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=146 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=147 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=148 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=149 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=150 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=151 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=152 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=153 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=154 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=155 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=156 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=157 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=158 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=159 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=160 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=161 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=162 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=163 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=164 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=165 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=166 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=167 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=168 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=169 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=170 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=171 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=172 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=173 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=174 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=175 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=176 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=177 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=178 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=179 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=180 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=181 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=182 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=183 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=184 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=185 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=186 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=187 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=188 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=189 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=190 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=191 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=192 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=193 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=194 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=195 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=196 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=197 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=198 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=199 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=200 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=201 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=202 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=203 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=204 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=205 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=206 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=207 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=208 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=209 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=210 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=211 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=212 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=213 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=214 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=215 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=216 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=217 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=218 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=219 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=220 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=221 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=222 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=223 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=224 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=225 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=226 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=227 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=228 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=229 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=230 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=231 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=232 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=233 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=234 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=235 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=236 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=237 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=238 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=239 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=240 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=241 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=242 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=243 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=244 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=245 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=246 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=247 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=248 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/1?page=249 -> 20 product links (10 new)
#   https://www.vertexnetworking.co.uk/category/1?page=250 -> 20 product links (20 new)
#   >>> progress: 5075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=251 -> 20 product links (20 new)
#   >>> progress: 5100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=252 -> 20 product links (20 new)
#   >>> progress: 5125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=253 -> 20 product links (20 new)
#   >>> progress: 5150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=254 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=255 -> 20 product links (20 new)
#   >>> progress: 5175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=256 -> 20 product links (20 new)
#   >>> progress: 5200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=257 -> 20 product links (20 new)
#   >>> progress: 5225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=258 -> 20 product links (20 new)
#   >>> progress: 5250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=259 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=260 -> 20 product links (20 new)
#   >>> progress: 5275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=261 -> 20 product links (20 new)
#   >>> progress: 5300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=262 -> 20 product links (20 new)
#   >>> progress: 5325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=263 -> 20 product links (20 new)
#   >>> progress: 5350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=264 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=265 -> 20 product links (20 new)
#   >>> progress: 5375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=266 -> 20 product links (20 new)
#   >>> progress: 5400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=267 -> 20 product links (20 new)
#   >>> progress: 5425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=268 -> 20 product links (20 new)
#   >>> progress: 5450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=269 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=270 -> 20 product links (20 new)
#   >>> progress: 5475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=271 -> 20 product links (20 new)
#   >>> progress: 5500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=272 -> 20 product links (20 new)
#   >>> progress: 5525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=273 -> 20 product links (20 new)
#   >>> progress: 5550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=274 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=275 -> 20 product links (20 new)
#   >>> progress: 5575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=276 -> 20 product links (20 new)
#   >>> progress: 5600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=277 -> 20 product links (20 new)
#   >>> progress: 5625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=278 -> 20 product links (20 new)
#   >>> progress: 5650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=279 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=280 -> 20 product links (20 new)
#   >>> progress: 5675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=281 -> 20 product links (20 new)
#   >>> progress: 5700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=282 -> 20 product links (20 new)
#   >>> progress: 5725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=283 -> 20 product links (20 new)
#   >>> progress: 5750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=284 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=285 -> 20 product links (20 new)
#   >>> progress: 5775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=286 -> 20 product links (20 new)
#   >>> progress: 5800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=287 -> 20 product links (20 new)
#   >>> progress: 5825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=288 -> 20 product links (20 new)
#   >>> progress: 5850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=289 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=290 -> 20 product links (20 new)
#   >>> progress: 5875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=291 -> 20 product links (20 new)
#   >>> progress: 5900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=292 -> 20 product links (20 new)
#   >>> progress: 5925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=293 -> 20 product links (20 new)
#   >>> progress: 5950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=294 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=295 -> 20 product links (20 new)
#   >>> progress: 5975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=296 -> 20 product links (20 new)
#   >>> progress: 6000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=297 -> 20 product links (20 new)
#   >>> progress: 6025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=298 -> 20 product links (20 new)
#   >>> progress: 6050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=299 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=300 -> 20 product links (20 new)
#   >>> progress: 6075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=301 -> 20 product links (20 new)
#   >>> progress: 6100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=302 -> 20 product links (20 new)
#   >>> progress: 6125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=303 -> 20 product links (20 new)
#   >>> progress: 6150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=304 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=305 -> 20 product links (20 new)
#   >>> progress: 6175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=306 -> 20 product links (20 new)
#   >>> progress: 6200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=307 -> 20 product links (20 new)
#   >>> progress: 6225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=308 -> 20 product links (20 new)
#   >>> progress: 6250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=309 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=310 -> 20 product links (20 new)
#   >>> progress: 6275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=311 -> 20 product links (20 new)
#   >>> progress: 6300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=312 -> 20 product links (20 new)
#   >>> progress: 6325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=313 -> 20 product links (20 new)
#   >>> progress: 6350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=314 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=315 -> 20 product links (20 new)
#   >>> progress: 6375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=316 -> 20 product links (20 new)
#   >>> progress: 6400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=317 -> 20 product links (20 new)
#   >>> progress: 6425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=318 -> 20 product links (20 new)
#   >>> progress: 6450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=319 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=320 -> 20 product links (20 new)
#   >>> progress: 6475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=321 -> 20 product links (20 new)
#   >>> progress: 6500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=322 -> 20 product links (20 new)
#   >>> progress: 6525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=323 -> 20 product links (20 new)
#   >>> progress: 6550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=324 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=325 -> 20 product links (20 new)
#   >>> progress: 6575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=326 -> 20 product links (20 new)
#   >>> progress: 6600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=327 -> 20 product links (20 new)
#   >>> progress: 6625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=328 -> 20 product links (20 new)
#   >>> progress: 6650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=329 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=330 -> 20 product links (20 new)
#   >>> progress: 6675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=331 -> 20 product links (20 new)
#   >>> progress: 6700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=332 -> 20 product links (20 new)
#   >>> progress: 6725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=333 -> 20 product links (20 new)
#   >>> progress: 6750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=334 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=335 -> 20 product links (20 new)
#   >>> progress: 6775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=336 -> 20 product links (20 new)
#   >>> progress: 6800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=337 -> 20 product links (20 new)
#   >>> progress: 6825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=338 -> 20 product links (20 new)
#   >>> progress: 6850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=339 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=340 -> 20 product links (20 new)
#   >>> progress: 6875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=341 -> 20 product links (20 new)
#   >>> progress: 6900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=342 -> 20 product links (20 new)
#   >>> progress: 6925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=343 -> 20 product links (20 new)
#   >>> progress: 6950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=344 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=345 -> 20 product links (20 new)
#   >>> progress: 6975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=346 -> 20 product links (20 new)
#   >>> progress: 7000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=347 -> 20 product links (20 new)
#   >>> progress: 7025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=348 -> 20 product links (20 new)
#   >>> progress: 7050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=349 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=350 -> 20 product links (20 new)
#   >>> progress: 7075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=351 -> 20 product links (20 new)
#   >>> progress: 7100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=352 -> 20 product links (20 new)
#   >>> progress: 7125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=353 -> 20 product links (20 new)
#   >>> progress: 7150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=354 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=355 -> 20 product links (20 new)
#   >>> progress: 7175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=356 -> 20 product links (20 new)
#   >>> progress: 7200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=357 -> 20 product links (20 new)
#   >>> progress: 7225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=358 -> 20 product links (20 new)
#   >>> progress: 7250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=359 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=360 -> 20 product links (20 new)
#   >>> progress: 7275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=361 -> 20 product links (20 new)
#   >>> progress: 7300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=362 -> 20 product links (20 new)
#   >>> progress: 7325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=363 -> 20 product links (20 new)
#   >>> progress: 7350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=364 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=365 -> 20 product links (20 new)
#   >>> progress: 7375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=366 -> 20 product links (20 new)
#   >>> progress: 7400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=367 -> 20 product links (20 new)
#   >>> progress: 7425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=368 -> 20 product links (20 new)
#   >>> progress: 7450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=369 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=370 -> 20 product links (20 new)
#   >>> progress: 7475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=371 -> 20 product links (20 new)
#   >>> progress: 7500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=372 -> 20 product links (20 new)
#   >>> progress: 7525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=373 -> 20 product links (20 new)
#   >>> progress: 7550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=374 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=375 -> 20 product links (20 new)
#   >>> progress: 7575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=376 -> 20 product links (20 new)
#   >>> progress: 7600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=377 -> 20 product links (20 new)
#   >>> progress: 7625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=378 -> 20 product links (20 new)
#   >>> progress: 7650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=379 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=380 -> 20 product links (20 new)
#   >>> progress: 7675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=381 -> 20 product links (20 new)
#   >>> progress: 7700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=382 -> 20 product links (20 new)
#   >>> progress: 7725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=383 -> 20 product links (20 new)
#   >>> progress: 7750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=384 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=385 -> 20 product links (20 new)
#   >>> progress: 7775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=386 -> 20 product links (20 new)
#   >>> progress: 7800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=387 -> 20 product links (20 new)
#   >>> progress: 7825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=388 -> 20 product links (20 new)
#   >>> progress: 7850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=389 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=390 -> 20 product links (20 new)
#   >>> progress: 7875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=391 -> 20 product links (20 new)
#   >>> progress: 7900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=392 -> 20 product links (20 new)
#   >>> progress: 7925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=393 -> 20 product links (20 new)
#   >>> progress: 7950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=394 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=395 -> 20 product links (20 new)
#   >>> progress: 7975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=396 -> 20 product links (20 new)
#   >>> progress: 8000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=397 -> 20 product links (20 new)
#   >>> progress: 8025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=398 -> 20 product links (20 new)
#   >>> progress: 8050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=399 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=400 -> 20 product links (20 new)
#   >>> progress: 8075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=401 -> 20 product links (20 new)
#   >>> progress: 8100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=402 -> 20 product links (20 new)
#   >>> progress: 8125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=403 -> 20 product links (20 new)
#   >>> progress: 8150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=404 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=405 -> 20 product links (20 new)
#   >>> progress: 8175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=406 -> 20 product links (20 new)
#   >>> progress: 8200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=407 -> 20 product links (20 new)
#   >>> progress: 8225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=408 -> 20 product links (20 new)
#   >>> progress: 8250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=409 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=410 -> 20 product links (20 new)
#   >>> progress: 8275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=411 -> 20 product links (20 new)
#   >>> progress: 8300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=412 -> 20 product links (20 new)
#   >>> progress: 8325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=413 -> 20 product links (20 new)
#   >>> progress: 8350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=414 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=415 -> 20 product links (20 new)
#   >>> progress: 8375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=416 -> 20 product links (20 new)
#   >>> progress: 8400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=417 -> 20 product links (20 new)
#   >>> progress: 8425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=418 -> 20 product links (20 new)
#   >>> progress: 8450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=419 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=420 -> 20 product links (20 new)
#   >>> progress: 8475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=421 -> 20 product links (20 new)
#   >>> progress: 8500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=422 -> 20 product links (20 new)
#   >>> progress: 8525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=423 -> 20 product links (20 new)
#   >>> progress: 8550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=424 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=425 -> 20 product links (20 new)
#   >>> progress: 8575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=426 -> 20 product links (20 new)
#   >>> progress: 8600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=427 -> 20 product links (20 new)
#   >>> progress: 8625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=428 -> 20 product links (20 new)
#   >>> progress: 8650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=429 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=430 -> 20 product links (20 new)
#   >>> progress: 8675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=431 -> 20 product links (20 new)
#   >>> progress: 8700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=432 -> 20 product links (20 new)
#   >>> progress: 8725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=433 -> 20 product links (20 new)
#   >>> progress: 8750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=434 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=435 -> 20 product links (20 new)
#   >>> progress: 8775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=436 -> 20 product links (20 new)
#   >>> progress: 8800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=437 -> 20 product links (20 new)
#   >>> progress: 8825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=438 -> 20 product links (20 new)
#   >>> progress: 8850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=439 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=440 -> 20 product links (20 new)
#   >>> progress: 8875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=441 -> 20 product links (20 new)
#   >>> progress: 8900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=442 -> 20 product links (20 new)
#   >>> progress: 8925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=443 -> 20 product links (20 new)
#   >>> progress: 8950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=444 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=445 -> 20 product links (20 new)
#   >>> progress: 8975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=446 -> 20 product links (20 new)
#   >>> progress: 9000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=447 -> 20 product links (20 new)
#   >>> progress: 9025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=448 -> 20 product links (20 new)
#   >>> progress: 9050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=449 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=450 -> 20 product links (20 new)
#   >>> progress: 9075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=451 -> 20 product links (20 new)
#   >>> progress: 9100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=452 -> 20 product links (20 new)
#   >>> progress: 9125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=453 -> 20 product links (20 new)
#   >>> progress: 9150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=454 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=455 -> 20 product links (20 new)
#   >>> progress: 9175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=456 -> 20 product links (20 new)
#   >>> progress: 9200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=457 -> 20 product links (20 new)
#   >>> progress: 9225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=458 -> 20 product links (20 new)
#   >>> progress: 9250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=459 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=460 -> 20 product links (20 new)
# ...
#   >>> progress: 13925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=693 -> 20 product links (20 new)
#   >>> progress: 13950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=694 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=695 -> 20 product links (20 new)
#   >>> progress: 13975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=696 -> 20 product links (20 new)
#   >>> progress: 14000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=697 -> 20 product links (20 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/mcp-220-00075-0b-supermicro-mcp-220-00075-0b-3-5%22-hot-swap-hdd-tray-w-hollow-panned-dummy-black.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/mcp-220-00075-0b-supermicro-mcp-220-00075-0b-3-5%22-hot-swap-hdd-tray-w-hollow-panned-dummy-black.html
#   >>> progress: 14025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=698 -> 20 product links (20 new)
#   >>> progress: 14050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=699 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=700 -> 20 product links (20 new)
#   >>> progress: 14075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=701 -> 20 product links (20 new)
#   >>> progress: 14100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=702 -> 20 product links (20 new)
#   >>> progress: 14125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=703 -> 20 product links (20 new)
#   >>> progress: 14150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=704 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=705 -> 20 product links (20 new)
#   >>> progress: 14175 products saved so far
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/mb992sk-b-icy-dock-full-metal-2-bay-2-5%C3%83%C2%A2%C3%A2%E2%80%9A%C2%AC%C3%82%EF%BF%BD-sata-sas-hdd-ssd-mobile-rack.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/mb992sk-b-icy-dock-full-metal-2-bay-2-5%C3%83%C2%A2%C3%A2%E2%80%9A%C2%AC%C3%82%EF%BF%BD-sata-sas-hdd-ssd-mobile-rack.html
#   https://www.vertexnetworking.co.uk/category/1?page=706 -> 20 product links (20 new)
#   >>> progress: 14200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=707 -> 20 product links (20 new)
#   >>> progress: 14225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=708 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=709 -> 20 product links (20 new)
#   >>> progress: 14250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=710 -> 20 product links (20 new)
#   >>> progress: 14275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=711 -> 20 product links (20 new)
#   >>> progress: 14300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=712 -> 20 product links (20 new)
#   >>> progress: 14325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=713 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=714 -> 20 product links (20 new)
#   >>> progress: 14350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=715 -> 20 product links (20 new)
#   >>> progress: 14375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=716 -> 20 product links (20 new)
#   >>> progress: 14400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=717 -> 20 product links (20 new)
#   >>> progress: 14425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=718 -> 20 product links (20 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/vy49d-dell-equalogic-tray-3-5%22-ps5500-ps6500-ps6510.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/vy49d-dell-equalogic-tray-3-5%22-ps5500-ps6500-ps6510.html
#   https://www.vertexnetworking.co.uk/category/1?page=719 -> 20 product links (20 new)
#   >>> progress: 14450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=720 -> 20 product links (20 new)
#   >>> progress: 14475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=721 -> 20 product links (20 new)
#   >>> progress: 14500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=722 -> 20 product links (20 new)
#   >>> progress: 14525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=723 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=724 -> 20 product links (20 new)
#   >>> progress: 14550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=725 -> 20 product links (20 new)
#   >>> progress: 14575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=726 -> 20 product links (20 new)
#   >>> progress: 14600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=727 -> 20 product links (20 new)
#   >>> progress: 14625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=728 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=729 -> 20 product links (20 new)
#   >>> progress: 14650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=730 -> 20 product links (20 new)
#   >>> progress: 14675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=731 -> 20 product links (20 new)
#   >>> progress: 14700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=732 -> 20 product links (20 new)
#   >>> progress: 14725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=733 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=734 -> 20 product links (20 new)
#   >>> progress: 14750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=735 -> 20 product links (20 new)
#   >>> progress: 14775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=736 -> 20 product links (20 new)
#   >>> progress: 14800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=737 -> 20 product links (20 new)
#   >>> progress: 14825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=738 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=739 -> 20 product links (20 new)
#   >>> progress: 14850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=740 -> 20 product links (20 new)
#   >>> progress: 14875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=741 -> 20 product links (20 new)
#   >>> progress: 14900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=742 -> 20 product links (20 new)
#   >>> progress: 14925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=743 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=744 -> 20 product links (20 new)
#   >>> progress: 14950 products saved so far
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/mz-v8p2t0b-am-samsung-980-pro-2tb-nvme%C3%82%C2%A0pci-express-4-0-solid-state-drive.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/mz-v8p2t0b-am-samsung-980-pro-2tb-nvme%C3%82%C2%A0pci-express-4-0-solid-state-drive.html
#   https://www.vertexnetworking.co.uk/category/1?page=745 -> 20 product links (20 new)
#   >>> progress: 14975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=746 -> 20 product links (20 new)
#   >>> progress: 15000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=747 -> 20 product links (20 new)
#   >>> progress: 15025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=748 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=749 -> 20 product links (20 new)
#   >>> progress: 15050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=750 -> 20 product links (20 new)
#   >>> progress: 15075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=751 -> 20 product links (20 new)
#   >>> progress: 15100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=752 -> 20 product links (20 new)
#   >>> progress: 15125 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=753 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=754 -> 20 product links (20 new)
#   >>> progress: 15150 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=755 -> 20 product links (20 new)
#   >>> progress: 15175 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=756 -> 20 product links (20 new)
#   >>> progress: 15200 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=757 -> 20 product links (20 new)
#   >>> progress: 15225 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=758 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=759 -> 20 product links (20 new)
#   >>> progress: 15250 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=760 -> 20 product links (20 new)
#   >>> progress: 15275 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=761 -> 20 product links (20 new)
#   >>> progress: 15300 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=762 -> 20 product links (20 new)
#   >>> progress: 15325 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=763 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=764 -> 20 product links (20 new)
#   >>> progress: 15350 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=765 -> 20 product links (20 new)
#   >>> progress: 15375 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=766 -> 20 product links (20 new)
#   >>> progress: 15400 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=767 -> 20 product links (20 new)
#   >>> progress: 15425 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=768 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=769 -> 20 product links (20 new)
#   >>> progress: 15450 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=770 -> 20 product links (20 new)
#   >>> progress: 15475 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=771 -> 20 product links (20 new)
#   >>> progress: 15500 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=772 -> 20 product links (20 new)
#   >>> progress: 15525 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=773 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=774 -> 20 product links (20 new)
#   >>> progress: 15550 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=775 -> 20 product links (20 new)
#   >>> progress: 15575 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=776 -> 20 product links (20 new)
#   >>> progress: 15600 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=777 -> 20 product links (20 new)
#   >>> progress: 15625 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=778 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=779 -> 20 product links (20 new)
#   >>> progress: 15650 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=780 -> 20 product links (20 new)
#   >>> progress: 15675 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=781 -> 20 product links (20 new)
#   >>> progress: 15700 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=782 -> 20 product links (20 new)
#   >>> progress: 15725 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=783 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=784 -> 20 product links (20 new)
#   >>> progress: 15750 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=785 -> 20 product links (20 new)
#   >>> progress: 15775 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=786 -> 20 product links (20 new)
#   >>> progress: 15800 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=787 -> 20 product links (20 new)
#   >>> progress: 15825 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=788 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=789 -> 20 product links (20 new)
#   >>> progress: 15850 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=790 -> 20 product links (20 new)
#   >>> progress: 15875 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=791 -> 20 product links (20 new)
#   >>> progress: 15900 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=792 -> 20 product links (20 new)
#   >>> progress: 15925 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=793 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=794 -> 20 product links (20 new)
#   >>> progress: 15950 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=795 -> 20 product links (20 new)
#   >>> progress: 15975 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=796 -> 20 product links (20 new)
#   >>> progress: 16000 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=797 -> 20 product links (20 new)
#   >>> progress: 16025 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=798 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/1?page=799 -> 20 product links (20 new)
#   >>> progress: 16050 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=800 -> 20 product links (20 new)
#   >>> progress: 16075 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=801 -> 20 product links (20 new)
#   >>> progress: 16100 products saved so far
#   https://www.vertexnetworking.co.uk/category/1?page=802 -> 20 product links (20 new)
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 330, in main()
#     329 writer.writerow(row)
# --> 330 csv_file.flush()  # write to disk immediately
#     331 scraped_count += 1
#
# PermissionError: [Errno 13] Permission denied
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# PermissionError: [Errno 13] Permission denied
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 347
#     343     print("Done (or safely stopped — rerun the script anytime to resume).")
#     346 if __name__ == "__main__":
# --> 347     main()
#
# Cell In[2], line 340, in main()
#     338     print("\n[stopped by user] Progress so far is safely saved in the CSV.")
#     339 finally:
# --> 340     csv_file.close()
#     342 print(f"\nTotal products in {OUTPUT_CSV}: {scraped_count}")
#     343 print("Done (or safely stopped — rerun the script anytime to resume).")
#
# PermissionError: [Errno 13] Permission denied
