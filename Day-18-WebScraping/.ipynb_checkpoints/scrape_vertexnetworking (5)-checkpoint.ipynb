# %% [markdown]
# # Vertex Networking Scraper (v7 — fixed category name bug)
#
# Columns: `category, title, description, image, price, part_number, url`
#
# **Fix:** category listing pages have the same generic 'Vertex Networking' header `<h1>` as product pages, which was overriding the real category name. Now skipped in favor of the actual category heading.
#
# **How to use this notebook:**
# 1. Run the **pip install** cell once.
# 2. In the scraper cell, find:
#    ```python
#    ONLY_THIS_CATEGORY = "/category/2"
#    ```
# 3. Change the number to whichever category you want to scrape next.
# 4. Run the scraper cell. Repeat with the next category number when done.
#
# All runs write to the same `vertexnetworking_products.csv` and skip product URLs already saved — safe to run category-by-category with zero duplicates.

# %%
# !pip install requests beautifulsoup4

# %%
#!/usr/bin/env python3
"""
Scraper for vertexnetworking.co.uk
Walks every category -> subcategory -> product listing (with pagination),
visits each product page, and writes:
    category, title, description, image, price, part_number, url
to a CSV file INCREMENTALLY (row-by-row) so no progress is lost if it's
interrupted or crashes partway through.

Field notes (learned from inspecting a real product page):
- title: their on-page <h1> is truncated by their template, so the title
  is instead derived from the Description text (which contains the full,
  untruncated name before "Product Condition:").
- price: some products don't have a price at all and instead show a
  "Request A Quote" / "Get A Quote" button. For those, the price cell is
  written as "Get a Quote for price" instead of being left blank or $0.00.
- part_number: pulled from the "Part Number: XXXXX" line on the page.
- image: their real product photo may be lazy-loaded (data-src / srcset
  instead of a plain src), so several attributes are checked.

Requirements:
    pip install requests beautifulsoup4

Usage:
    python scrape_vertexnetworking.py

Output:
    vertexnetworking_products.csv   (written to as it goes)

If you stop the script and run it again later, it will skip any product
URLs already present in the CSV, so it resumes instead of starting over.
Delete the CSV first if you want a completely fresh run.
"""

import csv
import os
import time
import re
from urllib.parse import urljoin

import requests
from bs4 import BeautifulSoup

BASE_URL = "https://www.vertexnetworking.co.uk"
OUTPUT_CSV = "vertexnetworking_products.csv"
REQUEST_DELAY = 0.75   # seconds between requests, be polite to their server
TIMEOUT = 20
PROGRESS_EVERY = 25    # print a running total every N products scraped

# ---------------------------------------------------------------------------
# RUN ONE CATEGORY AT A TIME
# ---------------------------------------------------------------------------
# Set this to the category you want to scrape THIS run, e.g. "/category/2".
# Only listing pages whose URL contains this text will be crawled — every
# other category is skipped entirely (not even its pages are fetched).
#
# Set it to None to scrape every category NOT listed in ALREADY_DONE_CATEGORIES.
#
# All runs share the same CSV, and already-scraped product URLs are always
# skipped — so running one category per session never creates duplicates.
ONLY_THIS_CATEGORY = "/category/2"

# Categories you've already fully finished in previous runs (used only when
# ONLY_THIS_CATEGORY is None, to skip them during a "run everything" pass).
ALREADY_DONE_CATEGORIES = ["/category/1"]

FIELDNAMES = ["category", "title", "description", "image", "price", "part_number", "url"]

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    )
}

GENERIC_HEADINGS = {"vertex networking", "home", "products", "detail"}
QUOTE_TEXT_PATTERN = re.compile(r"request\s*a?\s*quote|get\s*a?\s*quote", re.I)

session = requests.Session()
session.headers.update(HEADERS)


def get_soup(url):
    """Fetch a URL and return a BeautifulSoup object, or None on failure."""
    try:
        resp = session.get(url, timeout=TIMEOUT)
        resp.raise_for_status()
        time.sleep(REQUEST_DELAY)
        return BeautifulSoup(resp.text, "html.parser")
    except requests.RequestException as e:
        print(f"  [warn] failed to fetch {url}: {e}")
        return None


def discover_category_links():
    """Find every /category/N and /subcategory/N link from the homepage nav."""
    soup = get_soup(BASE_URL)
    if soup is None:
        raise SystemExit("Could not load homepage — aborting.")

    links = set()
    for a in soup.find_all("a", href=True):
        href = a["href"]
        full = urljoin(BASE_URL, href)
        if re.search(r"/(category|subcategory)/\d+", full):
            links.add(full)
    return sorted(links)


def get_category_label(soup, fallback_url):
    """Try to pull a readable category/subcategory name from a listing page.
    Their site has a generic 'Vertex Networking' <h1> (site header/logo) that
    appears before the real category heading, so that generic one is skipped."""
    for h in soup.find_all(["h1", "h2"]):
        text = h.get_text(strip=True)
        if text and text.lower() not in GENERIC_HEADINGS and len(text) > 1:
            return text

    title = soup.find("title")
    if title and title.get_text(strip=True):
        page_title = title.get_text(strip=True).split("|")[0].strip()
        if page_title.lower() not in GENERIC_HEADINGS:
            return page_title

    return fallback_url


def find_product_links(soup):
    """Extract all product detail page links from a listing page."""
    links = set()
    for a in soup.find_all("a", href=True):
        href = urljoin(BASE_URL, a["href"])
        if "/product/" in href and href.endswith(".html"):
            links.add(href)
    return links


def find_next_page(soup, current_url):
    """Look for a 'next page' pagination link."""
    next_link = soup.find("a", rel="next")
    if next_link and next_link.get("href"):
        return urljoin(current_url, next_link["href"])

    for a in soup.find_all("a", href=True):
        text = a.get_text(strip=True).lower()
        if text in ("next", "»", "next »", ">"):
            return urljoin(current_url, a["href"])

    return None


def clean_description_text(text):
    """Strip repeated 'Description' / 'Product Description' header words that
    get scooped up when we grab the whole section's text."""
    text = re.sub(r"^\s*(Description\s*)+", "", text, flags=re.I)
    text = re.sub(r"^\s*(Product Description\s*)+", "", text, flags=re.I)
    return text.strip()


def is_nonzero_price(text):
    digits = re.sub(r"[^\d.]", "", text)
    try:
        return float(digits) > 0
    except (ValueError, TypeError):
        return False


def extract_description(soup):
    desc_section = soup.find(["div", "section"], id=re.compile(r"description", re.I))
    if not desc_section:
        desc_section = soup.find(
            ["div", "section"],
            class_=re.compile(r"(product-desc|description|details)", re.I),
        )
    if desc_section:
        text = clean_description_text(desc_section.get_text(" ", strip=True))
        if text:
            return text

    meta_desc = soup.find("meta", attrs={"name": "description"})
    if meta_desc and meta_desc.get("content"):
        return meta_desc["content"].strip()
    return None


def extract_title(soup, description):
    # Priority 1: derive from the description — it reliably starts with
    # "PARTNUMBER - Brand ... Product Name" followed by "Product Condition:",
    # and is more complete than their on-page <h1> (which gets truncated).
    if description:
        parts = re.split(r"Product Condition\s*:", description, flags=re.I)
        candidate = parts[0].strip(" -")
        if candidate and len(candidate) > 3:
            return candidate

    # Priority 2: a real <h1>/<h2> that isn't the generic site header.
    for h in soup.find_all(["h1", "h2"]):
        text = h.get_text(strip=True)
        if text and text.lower() not in GENERIC_HEADINGS and len(text) > 3:
            return text

    # Priority 3: meta/og:title as an absolute last resort.
    og_title = soup.find("meta", property="og:title")
    if og_title and og_title.get("content"):
        return og_title["content"].strip()
    return None


def extract_image(soup):
    """Their real product photo may be lazy-loaded, so check several
    possible attributes, not just src. Real product images tend to come
    LATER in the page than banner/logo images, so prefer the last match."""
    candidates = []
    for img in soup.find_all("img"):
        for attr in ("src", "data-src", "data-original", "data-lazy-src", "data-image"):
            val = img.get(attr)
            if val and "/product_images/" in val:
                candidates.append(urljoin(BASE_URL, val))
                break
        else:
            srcset = img.get("srcset")
            if srcset and "/product_images/" in srcset:
                first_url = srcset.split(",")[0].strip().split(" ")[0]
                candidates.append(urljoin(BASE_URL, first_url))

    if candidates:
        return candidates[-1]

    og_image = soup.find("meta", property="og:image")
    if og_image and og_image.get("content"):
        return urljoin(BASE_URL, og_image["content"].strip())
    return None


def extract_price(soup):
    # 1. class="...price..." element with a non-zero value
    for tag in soup.find_all(["span", "div", "p"], class_=re.compile(r"price", re.I)):
        m = re.search(r"[\$£€]\s?[\d,]+\.?\d*", tag.get_text(" ", strip=True))
        if m and is_nonzero_price(m.group(0)):
            return m.group(0).strip()

    # 2. price-looking data embedded in <script> tags
    for script in soup.find_all("script"):
        if not script.string:
            continue
        m = re.search(r'"price"\s*:\s*"?\$?£?€?\s?([\d]+\.?\d*)"?', script.string)
        if m and is_nonzero_price(m.group(1)):
            return f"${m.group(1)}"

    # 3. any non-zero currency-looking value anywhere on the page
    #    (skips things like the header's "Shopping Cart: $0.00")
    for m in re.finditer(r"[\$£€]\s?[\d,]+\.\d{2}", soup.get_text(" ", strip=True)):
        if is_nonzero_price(m.group(0)):
            return m.group(0).strip()

    # 4. No price found at all — check if this is a "request a quote" item
    if soup.find(string=QUOTE_TEXT_PATTERN):
        return "Get a Quote for price"

    return None


def extract_part_number(soup):
    text = soup.get_text(" ", strip=True)
    m = re.search(r"Part\s*Number\s*:?\s*([A-Za-z0-9][A-Za-z0-9\-\/\.]*)", text, re.I)
    if m:
        return m.group(1).strip()
    return None


def scrape_product(url, category_label):
    """Visit a product page and extract all fields."""
    soup = get_soup(url)
    if soup is None:
        return None

    description = extract_description(soup)
    title = extract_title(soup, description)
    image = extract_image(soup)
    price = extract_price(soup)
    part_number = extract_part_number(soup)

    return {
        "category": category_label,
        "title": title or "",
        "description": description or "",
        "image": image or "",
        "price": price or "",
        "part_number": part_number or "",
        "url": url,
    }


def load_already_scraped():
    """If the CSV already exists (from a previous run), load which product
    URLs are already done so we can skip them and resume."""
    done = set()
    if os.path.exists(OUTPUT_CSV):
        with open(OUTPUT_CSV, "r", newline="", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            for row in reader:
                if row.get("url"):
                    done.add(row["url"])
    return done


def open_csv_writer():
    """Open the CSV in append mode, writing the header only if new."""
    file_exists = os.path.exists(OUTPUT_CSV)
    f = open(OUTPUT_CSV, "a", newline="", encoding="utf-8")
    writer = csv.DictWriter(f, fieldnames=FIELDNAMES)
    if not file_exists:
        writer.writeheader()
        f.flush()
    return f, writer


def main():
    already_done = load_already_scraped()
    if already_done:
        print(f"Resuming — {len(already_done)} products already in {OUTPUT_CSV}, will skip those.")

    csv_file, writer = open_csv_writer()
    scraped_count = len(already_done)

    try:
        print("Discovering category/subcategory links...")
        category_links = discover_category_links()
        print(f"Found {len(category_links)} category/subcategory links total.")

        if ONLY_THIS_CATEGORY:
            category_links = [c for c in category_links if ONLY_THIS_CATEGORY in c]
            print(f"ONLY_THIS_CATEGORY = '{ONLY_THIS_CATEGORY}' — "
                  f"{len(category_links)} matching link(s) will be crawled.")
        else:
            category_links = [
                c for c in category_links
                if not any(done in c for done in ALREADY_DONE_CATEGORIES)
            ]
            print(f"Skipping {ALREADY_DONE_CATEGORIES} — "
                  f"{len(category_links)} category links remain.")

        if not category_links:
            print("No matching category links found — check ONLY_THIS_CATEGORY "
                  "matches a real category URL (e.g. run once with it set to "
                  "None to see the full list printed above).")
            return

        for cat_index, cat_url in enumerate(category_links, start=1):
            print(f"\n[{cat_index}/{len(category_links)}] Category page: {cat_url}")
            page_url = cat_url
            visited_pages = set()

            while page_url and page_url not in visited_pages:
                visited_pages.add(page_url)
                soup = get_soup(page_url)
                if soup is None:
                    break

                label = get_category_label(soup, cat_url)
                product_links = find_product_links(soup)
                new_links = [p for p in product_links if p not in already_done]
                print(f"  {page_url} -> {len(product_links)} product links "
                      f"({len(new_links)} new)")

                for p_url in new_links:
                    row = scrape_product(p_url, label)
                    already_done.add(p_url)
                    if row:
                        writer.writerow(row)
                        csv_file.flush()  # write to disk immediately
                        scraped_count += 1
                        if scraped_count % PROGRESS_EVERY == 0:
                            print(f"  >>> progress: {scraped_count} products saved so far")

                page_url = find_next_page(soup, page_url)

    except KeyboardInterrupt:
        print("\n[stopped by user] Progress so far is safely saved in the CSV.")
    finally:
        csv_file.close()

    print(f"\nTotal products in {OUTPUT_CSV}: {scraped_count}")
    print("Done (or safely stopped — rerun the script anytime to resume).")


if __name__ == "__main__":
    main()
# Out:
# Resuming — 61769 products already in vertexnetworking_products.csv, will skip those.
# Discovering category/subcategory links...
# Found 120 category/subcategory links total.
# ONLY_THIS_CATEGORY = '/category/2' — 1 matching link(s) will be crawled.
#
# [1/1] Category page: https://www.vertexnetworking.co.uk/category/2
#   https://www.vertexnetworking.co.uk/category/2 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=2 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=3 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=4 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=5 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=6 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=7 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=8 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=9 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=10 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=11 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=12 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=13 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=14 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=15 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=16 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=17 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=18 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=19 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=20 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=21 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=22 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=23 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=24 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=25 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=26 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=27 -> 20 product links (1 new)
#   https://www.vertexnetworking.co.uk/category/2?page=28 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=29 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=30 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=31 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=32 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=33 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=34 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=35 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=36 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=37 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=38 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=39 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=40 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=41 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=42 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=43 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=44 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=45 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=46 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=47 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=48 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=49 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=50 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=51 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=52 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=53 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=54 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=55 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=56 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=57 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=58 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=59 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=60 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=61 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=62 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=63 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=64 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=65 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=66 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=67 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=68 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=69 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=70 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=71 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=72 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=73 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=74 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=75 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=76 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=77 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=78 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=79 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=80 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=81 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=82 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=83 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=84 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=85 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=86 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=87 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=88 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=89 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=90 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=91 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=92 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=93 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=94 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=95 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=96 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=97 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=98 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=99 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=100 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=101 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=102 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=103 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=104 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=105 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=106 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=107 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=108 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=109 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=110 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=111 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=112 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=113 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=114 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=115 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=116 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=117 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=118 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=119 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=120 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=121 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=122 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=123 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=124 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=125 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=126 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=127 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=128 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=129 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=130 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=131 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=132 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=133 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=134 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=135 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=136 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=137 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=138 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=139 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=140 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=142 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=143 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=144 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=145 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=146 -> 20 product links (1 new)
#   https://www.vertexnetworking.co.uk/category/2?page=147 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=148 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=149 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=150 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=151 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=152 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=153 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=154 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=155 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=156 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=157 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=158 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=159 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=160 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=161 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=162 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=163 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=164 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=165 -> 20 product links (1 new)
#   [warn] failed to fetch https://www.vertexnetworking.co.uk/product/mt46v32m4p-micron-%5B16mx16-4c%5D-micron-original-%5B16mx16-4c%5D-dram-memory-chip.html: 500 Server Error: Internal Server Error for url: https://www.vertexnetworking.co.uk/product/mt46v32m4p-micron-%5B16mx16-4c%5D-micron-original-%5B16mx16-4c%5D-dram-memory-chip.html
#   https://www.vertexnetworking.co.uk/category/2?page=166 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=167 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=168 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=169 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=170 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=171 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=172 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=173 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=174 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=175 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=176 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=177 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=178 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=179 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=180 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=181 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=182 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=183 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=184 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=185 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=186 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=187 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=188 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=189 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=190 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=191 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=192 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=193 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=194 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=195 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=196 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=197 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=198 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=199 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=200 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=201 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=202 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=203 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=204 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=205 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=206 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=207 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=208 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=209 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=210 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=211 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=212 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=213 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=214 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=215 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=216 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=217 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=218 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=219 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=220 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=221 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=222 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=223 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=224 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=225 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=226 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=227 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=228 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=229 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=230 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=231 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=232 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=233 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=234 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=235 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=236 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=237 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=238 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=239 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=240 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=241 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=242 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=243 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=244 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=245 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=246 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=247 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=248 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=249 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=250 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=251 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=252 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=253 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=254 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=255 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=256 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=257 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=258 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=259 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=260 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=261 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=262 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=263 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=264 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=265 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=266 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=267 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=268 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=269 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=270 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=271 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=272 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=273 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=274 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=275 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=276 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=277 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=278 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=279 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=280 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=281 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=282 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=283 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=284 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=285 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=286 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=287 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=288 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=289 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=290 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=291 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=292 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=293 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=294 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=295 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=296 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=297 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=298 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=299 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=300 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=301 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=302 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=303 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=304 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=305 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=306 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=307 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=308 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=309 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=310 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=311 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=312 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=313 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=314 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=315 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=316 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=317 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=318 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=319 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=320 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=321 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=322 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=323 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=324 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=325 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=326 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=327 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=328 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=329 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=330 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=331 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=332 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=333 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=334 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=335 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=336 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=337 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=338 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=339 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=340 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=341 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=342 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=343 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=344 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=345 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=346 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=347 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=348 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=349 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=350 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=351 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=352 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=353 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=354 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=355 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=356 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=357 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=358 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=359 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=360 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=361 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=362 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=363 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=364 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=365 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=366 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=367 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=368 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=369 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=370 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=371 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=372 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=373 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=374 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=375 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=376 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=377 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=378 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=379 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=380 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=381 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=382 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=383 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=384 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=385 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=386 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=387 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=388 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=389 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=390 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=391 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=392 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=393 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=394 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=395 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=396 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=397 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=398 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=399 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=400 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=401 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=402 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=403 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=404 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=405 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=406 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=407 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=408 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=409 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=410 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=411 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=412 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=413 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=414 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=415 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=416 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=417 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=418 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=419 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=420 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=421 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=422 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=423 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=424 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=425 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=426 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=427 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=428 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=429 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=430 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=431 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=432 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=433 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=434 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=435 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=436 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=437 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=438 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=439 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=440 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=441 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=442 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=443 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=444 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=445 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=446 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=447 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=448 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=449 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=450 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=451 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=452 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=453 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=454 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=455 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=456 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=457 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=458 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=459 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=460 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=461 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=462 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=463 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=464 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=465 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=466 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=467 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=468 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=469 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=470 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=471 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=472 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=473 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=474 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=475 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=476 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=477 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=478 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=479 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=480 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=481 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=482 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=483 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=484 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=485 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=486 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=487 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=488 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=489 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=490 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=491 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=492 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=493 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=494 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=495 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=496 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=497 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=498 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=499 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=500 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=501 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=502 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=503 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=504 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=505 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=506 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=507 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=508 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=509 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=510 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=511 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=512 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=513 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=514 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=515 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=516 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=517 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=518 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=519 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=520 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=521 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=522 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=523 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=524 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=525 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=526 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=527 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=528 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=529 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=530 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=531 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=532 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=533 -> 20 product links (1 new)
#   https://www.vertexnetworking.co.uk/category/2?page=534 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=535 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=536 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=537 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=538 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=539 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=540 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=541 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=542 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=543 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=544 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=545 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=546 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=547 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=548 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=549 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=550 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=551 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=552 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=553 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=554 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=555 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=556 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=557 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=558 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=559 -> 20 product links (0 new)
# ...
#   https://www.vertexnetworking.co.uk/category/2?page=893 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=894 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=895 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=896 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=897 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=898 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=899 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=900 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=901 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=902 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=903 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=904 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=905 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=906 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=907 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=908 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=909 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=910 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=911 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=912 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=913 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=914 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=915 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=916 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=917 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=918 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=919 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=920 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=921 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=922 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=923 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=924 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=925 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=926 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=927 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=928 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=929 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=930 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=931 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=932 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=933 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=934 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=935 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=936 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=937 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=938 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=939 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=940 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=941 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=942 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=943 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=944 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=945 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=946 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=947 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=948 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=949 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=950 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=951 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=952 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=953 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=954 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=955 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=956 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=957 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=958 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=959 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=960 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=961 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=962 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=963 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=964 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=965 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=966 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=967 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=968 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=969 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=970 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=971 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=972 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=973 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=974 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=975 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=976 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=977 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=978 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=979 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=980 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=981 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=982 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=983 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=984 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=985 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=986 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=987 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=988 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=989 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=990 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=991 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=992 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=993 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=994 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=995 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=996 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=997 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=998 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=999 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1000 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1001 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1002 -> 20 product links (0 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1003 -> 20 product links (5 new)
#   >>> progress: 61775 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1004 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1005 -> 20 product links (20 new)
#   >>> progress: 61800 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1006 -> 20 product links (20 new)
#   >>> progress: 61825 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1007 -> 20 product links (20 new)
#   >>> progress: 61850 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1008 -> 20 product links (20 new)
#   >>> progress: 61875 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1009 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1010 -> 20 product links (20 new)
#   >>> progress: 61900 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1011 -> 20 product links (20 new)
#   >>> progress: 61925 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1012 -> 20 product links (20 new)
#   >>> progress: 61950 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1013 -> 20 product links (20 new)
#   >>> progress: 61975 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1014 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1015 -> 20 product links (20 new)
#   >>> progress: 62000 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1016 -> 20 product links (20 new)
#   >>> progress: 62025 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1017 -> 20 product links (20 new)
#   >>> progress: 62050 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1018 -> 20 product links (20 new)
#   >>> progress: 62075 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1019 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1020 -> 20 product links (20 new)
#   >>> progress: 62100 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1021 -> 20 product links (20 new)
#   >>> progress: 62125 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1022 -> 20 product links (20 new)
#   >>> progress: 62150 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1023 -> 20 product links (20 new)
#   >>> progress: 62175 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1024 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1025 -> 20 product links (20 new)
#   >>> progress: 62200 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1026 -> 20 product links (20 new)
#   >>> progress: 62225 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1027 -> 20 product links (20 new)
#   >>> progress: 62250 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1028 -> 20 product links (20 new)
#   >>> progress: 62275 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1029 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1030 -> 20 product links (20 new)
#   >>> progress: 62300 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1031 -> 20 product links (20 new)
#   >>> progress: 62325 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1032 -> 20 product links (20 new)
#   >>> progress: 62350 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1033 -> 20 product links (20 new)
#   >>> progress: 62375 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1034 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1035 -> 20 product links (20 new)
#   >>> progress: 62400 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1036 -> 20 product links (20 new)
#   >>> progress: 62425 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1037 -> 20 product links (20 new)
#   >>> progress: 62450 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1038 -> 20 product links (20 new)
#   >>> progress: 62475 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1039 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1040 -> 20 product links (20 new)
#   >>> progress: 62500 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1041 -> 20 product links (20 new)
#   >>> progress: 62525 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1042 -> 20 product links (20 new)
#   >>> progress: 62550 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1043 -> 20 product links (20 new)
#   >>> progress: 62575 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1044 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1045 -> 20 product links (20 new)
#   >>> progress: 62600 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1046 -> 20 product links (20 new)
#   >>> progress: 62625 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1047 -> 20 product links (20 new)
#   >>> progress: 62650 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1048 -> 20 product links (20 new)
#   >>> progress: 62675 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1049 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1050 -> 20 product links (20 new)
#   >>> progress: 62700 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1051 -> 20 product links (20 new)
#   >>> progress: 62725 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1052 -> 20 product links (20 new)
#   >>> progress: 62750 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1053 -> 20 product links (20 new)
#   >>> progress: 62775 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1054 -> 20 product links (20 new)
#   https://www.vertexnetworking.co.uk/category/2?page=1055 -> 20 product links (20 new)
#   >>> progress: 62800 products saved so far
#   https://www.vertexnetworking.co.uk/category/2?page=1056 -> 20 product links (20 new)
#   >>> progress: 62825 products saved so far
