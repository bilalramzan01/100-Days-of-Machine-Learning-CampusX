# %% [markdown]
# # Fetching Data using Web Scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
requests.get("https://www.vertexnetworking.co.uk")
# Out:
# <Response [200]>

# %%
webpage = requests.get("https://www.vertexnetworking.co.uk").text

# %%
webpage
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<meta http-equiv="content-type" content="text/html;charset=UTF-8"/>\n<head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0">\n    <title>Vertex Networking - Your Trusted Source for Quality Computer Hardware, Servers & PC Components</title>\n    <meta name="keywords" content="Shop Server and PC Components Online | Top Computer Hardware Store" />\n    <meta name="description" content="Vertax Networking is a leading computer hardware store offering top-quality server and PC components. Shop online for the latest innovations in technology and exceptional customer service.">\n    <meta name="author" content="Vertex Networking">\n    <meta name="csrf-token" content="8UHXWCwWtfeAUSadl7XKaC6NFg8PvCnyLIatnIOe">\n    <link rel="apple-touch-icon" sizes="180x180" href="https://www.vertexnetworking.co.uk/frontend/favicon_io/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-16x16.png">\n    <link rel="manifest" href="https://www.vertexnetworking.co.uk/frontend/favicon_io/site.webmanifest">\n    <!-- Favicon -->\n    \n    <!-- Preload Font -->\n    <link rel="preload" href="https://www.vertexnetworking.co.uk/frontend/fonts/riode115b.ttf?5gap68" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-solid-900.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    <link rel="preload" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-brands-400.woff2" as="font" type="font/woff2" crossorigin="anonymous">\n    \n    <link rel="stylesheet" type="text/css" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/css/all.min.css">\n    <link rel="stylesheet" type="text/css" href="https://www.vertexnetworking.co.uk/frontend/vendor/animate/animate.min.css">\n    <!-- Plugins CSS File -->\n    \n    <link rel="stylesheet" type="text/css" href="https://www.vertexnetworking.co.uk/frontend/vendor/owl-carousel/owl.carousel.min.css">\n    \n    <!-- Main CSS File -->\n    <link rel="stylesheet" type="text/css" href="https://www.vertexnetworking.co.uk/frontend/css/demo6.min.css">\n    <link rel="stylesheet" type="text/css" href="https://www.vertexnetworking.co.uk/frontend/css/style.min.css">\n\n    <style>\n        .text-justify\n        {\n            text-align: justify;\n        }\n        .product-media {\n            display: flex;\n            justify-content: center;\n            align-items: center;\n            /* width: 280px; */\n            height: 315px !important; /* Adjust to your preferred size */\n            overflow: hidden; /* Ensures content outside the bounds is clipped */\n            position: relative;\n        }\n\n        .product-image {\n            width: 100% !important;\n            height: 100% !important;\n            object-fit: cover; /* Ensures the image fits within the container while maintaining aspect ratio */\n            object-position: center; /* Centers the image within the container */\n        }\n        .text-16\n        {\n            font-size: 16px !important;\n        }\n        .suggestion-box-mbl {\n            position: absolute;\n            left: 0;\n            background-color: #fff;\n            /* border: 1px solid #ccc; */\n            border-top: none;\n            border-radius: 0 0 4px 4px;\n            box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);\n            max-height: 400px;\n            overflow-y: auto;\n            padding: 0;\n            margin: 0;\n            list-style-type: none;\n            z-index: 1000;\n            width: 100%;\n        }\n\n        .search-div input.form-contr ...

# %%
soup = BeautifulSoup(webpage, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head><meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <title>Vertex Networking - Your Trusted Source for Quality Computer Hardware, Servers &amp; PC Components</title>
# <meta content="Shop Server and PC Components Online | Top Computer Hardware Store" name="keywords"/>
# <meta content="Vertax Networking is a leading computer hardware store offering top-quality server and PC components. Shop online for the latest innovations in technology and exceptional customer service." name="description"/>
# <meta content="Vertex Networking" name="author"/>
# <meta content="8UHXWCwWtfeAUSadl7XKaC6NFg8PvCnyLIatnIOe" name="csrf-token"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/site.webmanifest" rel="manifest"/>
# <!-- Favicon -->
# <!-- Preload Font -->
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/fonts/riode115b.ttf?5gap68" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/css/all.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/animate/animate.min.css" rel="stylesheet" type="text/css"/>
# <!-- Plugins CSS File -->
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/owl-carousel/owl.carousel.min.css" rel="stylesheet" type="text/css"/>
# <!-- Main CSS File -->
# <link href="https://www.vertexnetworking.co.uk/frontend/css/demo6.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/css/style.min.css" rel="stylesheet" type="text/css"/>
# <style>
#         .text-justify
#         {
#             text-align: justify;
#         }
#         .product-media {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             /* width: 280px; */
#             height: 315px !important; /* Adjust to your preferred size */
#             overflow: hidden; /* Ensures content outside the bounds is clipped */
#             position: relative;
#         }
#
#         .product-image {
#             width: 100% !important;
#             height: 100% !important;
#             object-fit: cover; /* Ensures the image fits within the container while maintaining aspect ratio */
#             object-position: center; /* Centers the image within the container */
#         }
#         .text-16
#         {
#             font-size: 16px !important;
#         }
#         .suggestion-box-mbl {
#             position: absolute;
#             left: 0;
#             background-color: #fff;
#             /* border: 1px solid #ccc; */
#             border-top: none;
#             border-radius: 0 0 4px 4px;
#             box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#             max-height: 400px;
#             overflow-y: auto;
#             padding: 0;
#             margin: 0;
#             list-style-type: none;
#             z-index: 1000;
#             width: 100%;
#         }
#
#         .search-div input.form-control
#         {
#             padding: 0 5rem 0 1.55rem;
#             border-radius: 5px;
#             border: 2px solid;
#             border-top-color: currentcolor;
#             border-right-color: currentcolor;
#             border-bottom-color: currentcolor;
#             border-left-color: currentcolor;
#             border-color: #44b3e9;
#             font-family: inherit;
#             background-color: #fff;
#             color: #999;
#         }
#
#         /* Show the div up to 767px */
#         @media (max-width: 767px) {
#             .search-div {
#                 display: block;
#                 padding: 10px;
#             }
#             .product-media
#             {
#                 height: 135px !important;
#             }
#         }
#
#         /* Hide the div after 767px */
#         @media (min-width: 768px) {
#             .search-div {
#                 display: none; /* Hide the div */
#             }
#         }
#     </style>
# </head><body class="home">
# <div class="page-wrapper">
# <style>
#     .search-container {
#         position: relative;
#         width: 300px;
#     }
#
#     .search-box {
#         width: 100%;
#         padding: 10px;
#         border: 1px solid #ccc;
#         border-radius: 4px;
#         font-size: 16px;
#     }
#
#     .suggestion-box {
#         position: absolute;
#         top: 100%;
#         left: 0;
#         right: 0;
#         background-color: #fff;
#         /* border: 1px solid #ccc; */
#         border-top: none;
#         border-radius: 0 0 4px 4px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         max-height: 200px;
#         overflow-y: auto;
#         padding: 0;
#         margin: 0;
#         list-style-type: none;
#         z-index: 1000;
#     }
#
#     .suggestion-item {
#         display: block;
#         padding: 10px;
#         color: #333;
#         text-decoration: none;
#         font-size: 16px;
#     }
#
#     .suggestion-item:hover {
#         background-color: #f1f1f1;
#     }
#
#     .no-suggestions {
#         padding: 10px;
#         color: #777;
#         font-style: italic;
#     }
# </style>
# <h1 class="d-none">Vertex Networking</h1>
# <header class="header">
# <div class="header-top" style="background-color: #f5f5f5">
# <div class="container">
# <div class="header-left">
# <p class="welcome-msg">Welcome to Vertex Networking!</p>
# </div>
# <div class="header-right">
# <!-- End DropDown Menu -->
# <a class="contact d-lg-show" href="https://www.vertexnetworking.co.uk/contact-us" style="font-size: 14px;color: black;"><i class="d-icon-map"></i>Contact Us</a>
# <a class="link-to-tab d-md-show" href="https://www.vertexnetworking.co.uk/login" style="font-size: 14px;color: black;"><i class="d-icon-user"></i>  Login</a>
# </div>
# </div>
# </div>
# <!-- End HeaderTop -->
# <div class="header-middle sticky-header fix-top sticky-content">
# <div class="container">
# <div class="header-left">
# <a class="mobile-menu-toggle" href="#">
# <i class="d-icon-bars2"></i>
# </a>
# <a class="logo" href="https://www.vertexnetworking.co.uk">
# <img alt="logo" src="https://www.vertexnetworking.co.uk/frontend/images/vertex-networking-logo.png"/>
# </a>
# <!-- End Logo -->
# <div class="header-search hs-simple">
# <form action="#" class="input-wrapper">
# <input autocomplete="off" class="form-control search-box" name="search" oninput="fetchSuggestions(this.value)" placeholder="Search..." required="" type="text"/>
# <div class="suggestion-box" id="suggestionBox"></div>
# </form>
# </div>
# <!-- End Header Search -->
# </div>
# <div class="header-right">
# <a class="icon-box icon-box-side" href="tel:+447367498493">
# <div class="icon-box-icon mr-0 mr-lg-2">
# <i class="d-icon-phone"></i>
# </div>
# <div class="icon-box-content d-lg-show">
# <h4 class="icon-box-title">Call Us Now:</h4>
# <p>+447367498493</p>
# </div>
# </a>
# <span class="divider"></span>
# <div class="dropdown cart-dropdown type2 off-canvas mr-0 mr-lg-2">
# <a class="label-block link" href="https://www.vertexnetworking.co.uk/cart">
# <div class="cart-label d-lg-show">
# <span class="cart-name">Shopping Cart:</span>
# <span class="cart-price">$ 0.00</span>
# </div>
# <i class="d-icon-bag"><span class="cart-count">0</span></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="header-bottom d-lg-show">
# <div class="container">
# <div class="header-left">
# <nav class="main-nav">
# <ul class="menu">
# <li class="active"><a href="https://www.vertexnetworking.co.uk">Home</a></li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/1">Hard Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/2">Solid State Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/3">Storage Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/4">Hard Drive Enclosure</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/5">Controllers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/6">Tape Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/7">Tape Media</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/8">Tape Libraries &amp; Autoloaders</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/9">USB Flash Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/10">Memory Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/11">I/O Cards/Panel</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/12">Floppy Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/13">Network Storage Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/14">Host Bus Adapter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/15">Host Channel Adapter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/16">Optical Drives &amp; Burners</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/17">Optical Media</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/18">Storage Array</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/2">Memory</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/19">Server Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/20">Desktop Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/21">Laptop Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/22">Printer Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/23">Network Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/24">Gaming Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/25">Cache Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/26">Flash Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/27">Memory Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/28">Memory Chips DRAM</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/29">RDRAM - Rambus Memory</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/3">Network &amp; Accessories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/30">Management Controller Module</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/31">Wireless Networking</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/32">Network Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/33">Routers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/34">VoIP Gateways</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/35">Media Converter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/36">Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/37">Network Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/38">Transceivers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/39">Switch Module</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/40">Modems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/41">Powerline Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/42">Power Over Ethernet Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/43">Network Security &amp; Firewall Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/44">Terminal Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/45">IP Phones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/46">Print Servers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/4">PC &amp; Servers</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/47">Laptop PC</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/48">Laptop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/49">Workstation Systems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/50">Workstation Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/51">Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/52">Server Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/53">Desktops</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/54">Desktop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/55">Tablet PC</a></li>
# </ul>
# </li>
# <li class="submenu">
# <a href="#">Other Categories</a>
# <ul>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/6">Motherboards</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/59">Desktop Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/60">Server Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/61">Laptop Motherboards</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/7">Printers &amp; Scanners</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/62">Printers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/63">Printer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/64">Printer Cartridges</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/65">Scanner Faxes &amp; Copiers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/8">Power Equipment</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/66">Power Supplies</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/67">Power Adapters &amp; Chargers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/68">UPS</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/69">PDUs</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/70">Surge Suppressors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/71">Power Bank</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/72">Batteries</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/73">Power Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/9">Processors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/74">Server Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/75">Desktop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/76">Laptop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/77">Processor Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/78">VRM</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/11">Audio Components</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/84">Headphone &amp; Headsets</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/85">Microphones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/86">Sound Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/87">Speakers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/12">Input Devices</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/88">KVM Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/89">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/90">Mouse</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/91">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/92">Input Device Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/14">Monitors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/99">LCD/LED Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/100">CRT Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/101">Laptop Replacement Screen</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/102">Monitor Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/15">System Cooling Parts</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/103">Heatsink</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/104">CPU Fans</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/105">CPU Fans / Heatsinks</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/106">Thermal Compund / Grease</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/107">Fan Tray</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/16">Cables</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/108">Network Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/109">Audio &amp; Video Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/110">KVM Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/111">Storage &amp; Data Transfer Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/112">System &amp; Power Cables</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/17">Cameras</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/113">Surveillance Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/114">Webcams</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/115">Digital Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/116">Camera Parts &amp; Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/13">More Categories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/97">Computer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/98">ICs &amp; Micro Chips</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <main class="main">
# <section class="search-div">
# <div class="container">
# <form action="#" class="input-wrapper">
# <input autocomplete="off" class="form-control search-box" name="search" oninput="fetchSuggestionsMbl(this.value)" placeholder="Search..." required="" type="text"/>
# <div class="suggestion-box-mbl" id="suggestionBoxMbl"></div>
# </form>
# </div>
# </section>
# <div class="page-content">
# <style>
#     .gradient-bg {
#         background: linear-gradient(to right, #a6f0ff, #b5a2ff);
#         padding: 30px;
#     }
#     .gradient-bg img {
#         max-width: 100%;
#         height: auto;
#     }
#     .w-80 {
#         width: 80%;
#     }
#
#     .w-20 {
#         width: 20%;
#     }
# </style>
# <div class="container mt-4">
# <div class="row g-4">
# <div class="col-lg-8 col-md-12 d-flex">
# <div class="d-flex align-items-center justify-content-between w-100 p-3">
# <img alt="Headset" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-1st.png"/>
# </div>
# </div>
# <div class="col-lg-4 col-md-6 d-flex flex-column">
# <div class="equal-height">
# <div class="col-md-12 mt-3 mt-md-0">
# <div class="d-flex align-items-center justify-content-between p-3">
# <img alt="VoIP Phone" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-2nd.png"/>
# </div>
# </div>
# <div class="col-md-12 mt-3">
# <div class="d-flex align-items-center justify-content-between p-3">
# <img alt="VoIP Phone" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-3rd.png"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section>
# <h2 class="title title-center mt-10">Feature Brands</h2>
# <div class="code-template">
# <div class="owl-carousel owl-theme container owl-nav-full cols-lg-2 cols-md-3 cols-sm-2 cols-1 owl-nav-arrow appear-animate" data-owl-options="{
#                         'nav': false,
#                         'loop': true,
#                         'dots': true,
#                         'autoplay': true,
#                         'autoplayTimeout': 2000,
#                         'smartSpeed': 700,
#                         'items': 8,
#                         'margin': 20,
#                         'responsive': {
#                             '0': {
#                                 'items': 2
#                             },
#                             '576': {
#                                 'items': 3
#                             },
#                             '768': {
#                                 'items': 6
#                             },
#                             '992': {
#                                 'items': 8
#                             }
#                         }
#                     }">
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074611-hp.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074712-wd.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074652-ibm.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074664-toshiba.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074688-lenovo.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074631-cisco.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074640-fujitsu.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074804-samsung.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074675-kingston.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074721-ubiquiti.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074703-tp-link.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074794-seagate.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="product-wrapper mb-10 pb-8 appear-animate grey-section" style="display: none;">
# <div class="container">
# <h2 class="title title-center mt-10">Feature Products</h2>
# <div class="toolbox">
# <div class="toolbox-left">
# <ul class="nav-filters product-filters" data-target="#products-grid">
# <li>
# <a class="nav-filter active font-weight-semi-bold" data-filter="*" href="#">All</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".1" href="#">Storage Device</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".2" href="#">Memory</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".3" href="#">Network &amp; Accessories</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".4" href="#">PC &amp; Servers</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".5" href="#">Softwares</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row grid products-grid mb-2" data-grid-options="{
#                 'masonry': { 'columnWidth': '' } }" id="products-grid">
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe75731c_ST900MP0006-o.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">Seagate ST900MP0006 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$179.91 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe7cbeb8_FW4KG.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">Dell FW4KG 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$92.69 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe838db7_870795-001.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">HPE 870795-001 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$297.95 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe8a770b_FXG2N.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">Dell FXG2N 2TB 7200RPM SATA 6Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$149.83 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe9194d4_870759-B21.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">HPE 870759-B21 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$290.44 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe98094c_KT3WC.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">Dell KT3WC 1TB 7200RPM SATA 6Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$87.43 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe9d1ca3_867254-003.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">HPE 867254-003 900GB 15000RPM SAS 12Gb/s 2.5-Inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$290.44 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffea45a3c_KRM6X.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">Dell KRM6X 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$142.32 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section>
# <div class="container">
# <h2 class="title title-center mt-10">Feature Category</h2>
# <div class="row cols-2 cols-sm-3 cols-md-4 cols-lg-5">
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/1">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015099-rb_23945-1-2.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Storage Device</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/2">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015053-two-ram-1-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Memory</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/3">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015232-network-switch-isolated-solid-white-background-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Network &amp; Accessories</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/4">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015354-server-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">PC &amp; Servers</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/5">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015462-rb_2148684987-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Softwares</h4>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="container">
# <section class="mt-10 pt-2">
# <h2 class="title title-center">Feature Products</h2>
# <div class="code-template">
# <div class="row product-wrapper equal-height">
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe75731c_ST900MP0006-o.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Quick View">Buy Now</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">Seagate ST900MP0006 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price"> $179.91</ins>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe7cbeb8_FW4KG.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Quick View">Buy Now</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">Dell FW4KG 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price"> $92.69</ins>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe838db7_870795-001.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Quick View">Buy Now</a>
# ...
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/41">Powerline Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/42">Power Over Ethernet Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/43">Network Security &amp; Firewall Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/44">Terminal Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/45">IP Phones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/46">Print Servers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/4">PC &amp; Servers</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/47">Laptop PC</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/48">Laptop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/49">Workstation Systems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/50">Workstation Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/51">Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/52">Server Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/53">Desktops</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/54">Desktop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/55">Tablet PC</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/6">Motherboards</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/59">Desktop Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/60">Server Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/61">Laptop Motherboards</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/7">Printers &amp; Scanners</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/62">Printers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/63">Printer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/64">Printer Cartridges</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/65">Scanner Faxes &amp; Copiers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/8">Power Equipment</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/66">Power Supplies</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/67">Power Adapters &amp; Chargers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/68">UPS</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/69">PDUs</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/70">Surge Suppressors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/71">Power Bank</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/72">Batteries</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/73">Power Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/9">Processors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/74">Server Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/75">Desktop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/76">Laptop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/77">Processor Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/78">VRM</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/11">Audio Components</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/84">Headphone &amp; Headsets</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/85">Microphones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/86">Sound Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/87">Speakers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/12">Input Devices</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/88">KVM Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/89">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/90">Mouse</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/91">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/92">Input Device Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/14">Monitors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/99">LCD/LED Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/100">CRT Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/101">Laptop Replacement Screen</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/102">Monitor Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/15">System Cooling Parts</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/103">Heatsink</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/104">CPU Fans</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/105">CPU Fans / Heatsinks</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/106">Thermal Compund / Grease</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/107">Fan Tray</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/16">Cables</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/108">Network Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/109">Audio &amp; Video Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/110">KVM Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/111">Storage &amp; Data Transfer Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/112">System &amp; Power Cables</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/17">Cameras</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/113">Surveillance Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/114">Webcams</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/115">Digital Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/116">Camera Parts &amp; Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/13">More Categories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/97">Computer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/98">ICs &amp; Micro Chips</a></li>
# </ul>
# </li>
# <li><a href="https://www.vertexnetworking.co.uk/about-us">About US</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/contact-us">Contact US</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/login">Login</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/cart">My Cart</a></li>
# </ul>
# <!-- End of MobileMenu -->
# </div>
# </div>
# <!-- Plugins JS File -->
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery/jquery.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/elevatezoom/jquery.elevatezoom.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/magnific-popup/jquery.magnific-popup.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery.floating/jquery.floating.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/owl-carousel/owl.carousel.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/imagesloaded/imagesloaded.pkgd.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/isotope/isotope.pkgd.min.js"></script>
# <!-- Main JS File -->
# <script src="https://www.vertexnetworking.co.uk/frontend/js/main.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery.count-to/jquery-numerator.min.js"></script>
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
#     var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
#     (function(){
#     var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
#     s1.async=true;
#     s1.src='https://embed.tawk.to/677c057baf5bfec1dbe76716/1igu7ar24';
#     s1.charset='UTF-8';
#     s1.setAttribute('crossorigin','*');
#     s0.parentNode.insertBefore(s1,s0);
#     })();
#     </script>
# <!--End of Tawk.to Script-->
# <script>
#         function addToCart(val)
#         {
#             // CSRF token for Laravel security
#             const csrfToken = $('meta[name="csrf-token"]').attr('content');
#             const item_qty = $('#item_qty').val();
#
#             // AJAX request
#             $.ajax({
#                 url: '/cart/add', // Replace with your route for adding to cart
#                 type: 'POST',
#                 data: {
#                     _token: csrfToken, // CSRF token for Laravel
#                     product_id: val,
#                     product_qty: item_qty,
#                 },
#                 success: function (response) {
#                     // console.log(response);
#
#                     if (response.status === 'success') {
#                         // alert('Product added to cart!');
#                         // Update cart count (optional)
#                         $('.cart-count').text(response.cart_count);
#                         $('.cart-price').text('$ '+response.cart_price);
#                     } else {
#                         alert(response.message);
#                     }
#                 },
#                 error: function (xhr, status, error) {
#                     console.error('Error adding product to cart:', xhr.responseText);
#                     alert('An error occurred while adding the product to the cart.');
#                 }
#             });
#         }
#
#         function RemoveProductFromCart(val)
#         {
#             // CSRF token for Laravel security
#             const csrfToken = $('meta[name="csrf-token"]').attr('content');
#
#             // AJAX request
#             $.ajax({
#                 url: '/cart/remove/'+val, // Replace with your route for adding to cart
#                 type: 'GET',
#                 data: {
#                     _token: csrfToken, // CSRF token for Laravel
#                 },
#                 success: function (response) {
#                     // console.log(response);
#
#                     if (response.status === 'success') {
#                         // alert('Product added to cart!');
#                         // Update cart count (optional)
#                         $('.cart-count').text(response.cart_count);
#                         $('.cart-price').text('$ '+response.cart_price);
#                         $('.summary-total-price').text('$ '+response.cart_price);
#                         const targetId = 'tr-'+val;
#                         $(`tr[data-id="${targetId}"]`).hide();
#                     } else {
#                         alert(response.message);
#                     }
#                 },
#                 error: function (xhr, status, error) {
#                     console.error('Error adding product to cart:', xhr.responseText);
#                     alert('An error occurred while adding the product to the cart.');
#                 }
#             });
#         }
#     </script>
# <script>
#         function fetchSuggestions(query) {
#             const suggestionBox = document.getElementById("suggestionBox");
#             suggestionBox.innerHTML = ""; // Clear previous suggestions
#
#             if (query.trim() === "") {
#                 suggestionBox.style.display = "none";
#                 return;
#             }
#
#             $.ajax({
#                 url: "https://www.vertexnetworking.co.uk/search-products",
#                 method: "GET",
#                 data: { query: query },
#                 success: function (response) {
#                     if (response.length > 0) {
#                         response.forEach(product => {
#                             const li = document.createElement("li");
#                             const anchor = document.createElement("a");
#                             anchor.href = `/product/${product.slug}`; // Replace with your product details route
#                             anchor.textContent = `${product.product_name}`;
#                             anchor.className = "suggestion-item";
#                             li.appendChild(anchor);
#                             suggestionBox.appendChild(li);
#                         });
#                         suggestionBox.style.display = "block";
#                     } else {
#                         const li = document.createElement("li");
#                         li.className = "no-suggestions";
#                         li.textContent = "No suggestions found";
#                         suggestionBox.appendChild(li);
#                         suggestionBox.style.display = "block";
#                     }
#                 },
#                 error: function () {
#                     const li = document.createElement("li");
#                     li.className = "no-suggestions";
#                     li.textContent = "Error fetching suggestions";
#                     suggestionBox.appendChild(li);
#                     suggestionBox.style.display = "block";
#                 }
#             });
#         }
#     </script>
# <script>
#     function fetchSuggestionsMbl(query) {
#         const suggestionBox = document.getElementById("suggestionBoxMbl");
#         suggestionBox.innerHTML = ""; // Clear previous suggestions
#
#         if (query.trim() === "") {
#             suggestionBox.style.display = "none";
#             return;
#         }
#
#         $.ajax({
#             url: "https://www.vertexnetworking.co.uk/search-products",
#             method: "GET",
#             data: { query: query },
#             success: function (response) {
#                 if (response.length > 0) {
#                     response.forEach(product => {
#                         const li = document.createElement("li");
#                         const anchor = document.createElement("a");
#                         anchor.href = `/product/${product.slug}`; // Replace with your product details route
#                         anchor.textContent = `${product.product_name}`;
#                         anchor.className = "suggestion-item";
#                         li.appendChild(anchor);
#                         suggestionBox.appendChild(li);
#                     });
#                     suggestionBox.style.display = "block";
#                 } else {
#                     const li = document.createElement("li");
#                     li.className = "no-suggestions";
#                     li.textContent = "No suggestions found";
#                     suggestionBox.appendChild(li);
#                     suggestionBox.style.display = "block";
#                 }
#             },
#             error: function () {
#                 const li = document.createElement("li");
#                 li.className = "no-suggestions";
#                 li.textContent = "Error fetching suggestions";
#                 suggestionBox.appendChild(li);
#                 suggestionBox.style.display = "block";
#             }
#         });
#     }
# </script>
# </body>
# <script>'undefined'=== typeof _trfq || (window._trfq = []);'undefined'=== typeof _trfd && (window._trfd=[]),_trfd.push({'tccl.baseHost':'secureserver.net'},{'ap':'cpbh-mt'},{'server':'sxb1plmcpnl480540'},{'dcenter':'sxb1'},{'cp_id':'10221597'},{'cp_cl':'8'}) // Monitoring performance to make your website faster. If you want to opt-out, please contact web hosting support.</script><script src="https://img1.wsimg.com/traffic-assets/js/tccl.min.js"></script></html>

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en">
# <head><meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <title>Vertex Networking - Your Trusted Source for Quality Computer Hardware, Servers &amp; PC Components</title>
# <meta content="Shop Server and PC Components Online | Top Computer Hardware Store" name="keywords"/>
# <meta content="Vertax Networking is a leading computer hardware store offering top-quality server and PC components. Shop online for the latest innovations in technology and exceptional customer service." name="description"/>
# <meta content="Vertex Networking" name="author"/>
# <meta content="8UHXWCwWtfeAUSadl7XKaC6NFg8PvCnyLIatnIOe" name="csrf-token"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/favicon_io/site.webmanifest" rel="manifest"/>
# <!-- Favicon -->
# <!-- Preload Font -->
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/fonts/riode115b.ttf?5gap68" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/webfonts/fa-brands-400.woff2" rel="preload" type="font/woff2"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/fontawesome-free/css/all.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/animate/animate.min.css" rel="stylesheet" type="text/css"/>
# <!-- Plugins CSS File -->
# <link href="https://www.vertexnetworking.co.uk/frontend/vendor/owl-carousel/owl.carousel.min.css" rel="stylesheet" type="text/css"/>
# <!-- Main CSS File -->
# <link href="https://www.vertexnetworking.co.uk/frontend/css/demo6.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://www.vertexnetworking.co.uk/frontend/css/style.min.css" rel="stylesheet" type="text/css"/>
# <style>
#         .text-justify
#         {
#             text-align: justify;
#         }
#         .product-media {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             /* width: 280px; */
#             height: 315px !important; /* Adjust to your preferred size */
#             overflow: hidden; /* Ensures content outside the bounds is clipped */
#             position: relative;
#         }
#
#         .product-image {
#             width: 100% !important;
#             height: 100% !important;
#             object-fit: cover; /* Ensures the image fits within the container while maintaining aspect ratio */
#             object-position: center; /* Centers the image within the container */
#         }
#         .text-16
#         {
#             font-size: 16px !important;
#         }
#         .suggestion-box-mbl {
#             position: absolute;
#             left: 0;
#             background-color: #fff;
#             /* border: 1px solid #ccc; */
#             border-top: none;
#             border-radius: 0 0 4px 4px;
#             box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#             max-height: 400px;
#             overflow-y: auto;
#             padding: 0;
#             margin: 0;
#             list-style-type: none;
#             z-index: 1000;
#             width: 100%;
#         }
#
#         .search-div input.form-control
#         {
#             padding: 0 5rem 0 1.55rem;
#             border-radius: 5px;
#             border: 2px solid;
#             border-top-color: currentcolor;
#             border-right-color: currentcolor;
#             border-bottom-color: currentcolor;
#             border-left-color: currentcolor;
#             border-color: #44b3e9;
#             font-family: inherit;
#             background-color: #fff;
#             color: #999;
#         }
#
#         /* Show the div up to 767px */
#         @media (max-width: 767px) {
#             .search-div {
#                 display: block;
#                 padding: 10px;
#             }
#             .product-media
#             {
#                 height: 135px !important;
#             }
#         }
#
#         /* Hide the div after 767px */
#         @media (min-width: 768px) {
#             .search-div {
#                 display: none; /* Hide the div */
#             }
#         }
#     </style>
# </head><body class="home">
# <div class="page-wrapper">
# <style>
#     .search-container {
#         position: relative;
#         width: 300px;
#     }
#
#     .search-box {
#         width: 100%;
#         padding: 10px;
#         border: 1px solid #ccc;
#         border-radius: 4px;
#         font-size: 16px;
#     }
#
#     .suggestion-box {
#         position: absolute;
#         top: 100%;
#         left: 0;
#         right: 0;
#         background-color: #fff;
#         /* border: 1px solid #ccc; */
#         border-top: none;
#         border-radius: 0 0 4px 4px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         max-height: 200px;
#         overflow-y: auto;
#         padding: 0;
#         margin: 0;
#         list-style-type: none;
#         z-index: 1000;
#     }
#
#     .suggestion-item {
#         display: block;
#         padding: 10px;
#         color: #333;
#         text-decoration: none;
#         font-size: 16px;
#     }
#
#     .suggestion-item:hover {
#         background-color: #f1f1f1;
#     }
#
#     .no-suggestions {
#         padding: 10px;
#         color: #777;
#         font-style: italic;
#     }
# </style>
# <h1 class="d-none">Vertex Networking</h1>
# <header class="header">
# <div class="header-top" style="background-color: #f5f5f5">
# <div class="container">
# <div class="header-left">
# <p class="welcome-msg">Welcome to Vertex Networking!</p>
# </div>
# <div class="header-right">
# <!-- End DropDown Menu -->
# <a class="contact d-lg-show" href="https://www.vertexnetworking.co.uk/contact-us" style="font-size: 14px;color: black;"><i class="d-icon-map"></i>Contact Us</a>
# <a class="link-to-tab d-md-show" href="https://www.vertexnetworking.co.uk/login" style="font-size: 14px;color: black;"><i class="d-icon-user"></i>  Login</a>
# </div>
# </div>
# </div>
# <!-- End HeaderTop -->
# <div class="header-middle sticky-header fix-top sticky-content">
# <div class="container">
# <div class="header-left">
# <a class="mobile-menu-toggle" href="#">
# <i class="d-icon-bars2"></i>
# </a>
# <a class="logo" href="https://www.vertexnetworking.co.uk">
# <img alt="logo" src="https://www.vertexnetworking.co.uk/frontend/images/vertex-networking-logo.png"/>
# </a>
# <!-- End Logo -->
# <div class="header-search hs-simple">
# <form action="#" class="input-wrapper">
# <input autocomplete="off" class="form-control search-box" name="search" oninput="fetchSuggestions(this.value)" placeholder="Search..." required="" type="text"/>
# <div class="suggestion-box" id="suggestionBox"></div>
# </form>
# </div>
# <!-- End Header Search -->
# </div>
# <div class="header-right">
# <a class="icon-box icon-box-side" href="tel:+447367498493">
# <div class="icon-box-icon mr-0 mr-lg-2">
# <i class="d-icon-phone"></i>
# </div>
# <div class="icon-box-content d-lg-show">
# <h4 class="icon-box-title">Call Us Now:</h4>
# <p>+447367498493</p>
# </div>
# </a>
# <span class="divider"></span>
# <div class="dropdown cart-dropdown type2 off-canvas mr-0 mr-lg-2">
# <a class="label-block link" href="https://www.vertexnetworking.co.uk/cart">
# <div class="cart-label d-lg-show">
# <span class="cart-name">Shopping Cart:</span>
# <span class="cart-price">$ 0.00</span>
# </div>
# <i class="d-icon-bag"><span class="cart-count">0</span></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="header-bottom d-lg-show">
# <div class="container">
# <div class="header-left">
# <nav class="main-nav">
# <ul class="menu">
# <li class="active"><a href="https://www.vertexnetworking.co.uk">Home</a></li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/1">Hard Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/2">Solid State Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/3">Storage Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/4">Hard Drive Enclosure</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/5">Controllers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/6">Tape Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/7">Tape Media</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/8">Tape Libraries &amp; Autoloaders</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/9">USB Flash Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/10">Memory Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/11">I/O Cards/Panel</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/12">Floppy Drives</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/13">Network Storage Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/14">Host Bus Adapter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/15">Host Channel Adapter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/16">Optical Drives &amp; Burners</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/17">Optical Media</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/18">Storage Array</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/2">Memory</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/19">Server Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/20">Desktop Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/21">Laptop Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/22">Printer Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/23">Network Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/24">Gaming Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/25">Cache Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/26">Flash Memory</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/27">Memory Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/28">Memory Chips DRAM</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/29">RDRAM - Rambus Memory</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/3">Network &amp; Accessories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/30">Management Controller Module</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/31">Wireless Networking</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/32">Network Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/33">Routers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/34">VoIP Gateways</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/35">Media Converter</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/36">Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/37">Network Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/38">Transceivers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/39">Switch Module</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/40">Modems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/41">Powerline Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/42">Power Over Ethernet Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/43">Network Security &amp; Firewall Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/44">Terminal Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/45">IP Phones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/46">Print Servers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/4">PC &amp; Servers</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/47">Laptop PC</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/48">Laptop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/49">Workstation Systems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/50">Workstation Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/51">Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/52">Server Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/53">Desktops</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/54">Desktop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/55">Tablet PC</a></li>
# </ul>
# </li>
# <li class="submenu">
# <a href="#">Other Categories</a>
# <ul>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/6">Motherboards</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/59">Desktop Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/60">Server Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/61">Laptop Motherboards</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/7">Printers &amp; Scanners</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/62">Printers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/63">Printer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/64">Printer Cartridges</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/65">Scanner Faxes &amp; Copiers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/8">Power Equipment</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/66">Power Supplies</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/67">Power Adapters &amp; Chargers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/68">UPS</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/69">PDUs</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/70">Surge Suppressors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/71">Power Bank</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/72">Batteries</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/73">Power Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/9">Processors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/74">Server Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/75">Desktop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/76">Laptop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/77">Processor Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/78">VRM</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/11">Audio Components</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/84">Headphone &amp; Headsets</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/85">Microphones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/86">Sound Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/87">Speakers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/12">Input Devices</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/88">KVM Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/89">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/90">Mouse</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/91">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/92">Input Device Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/14">Monitors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/99">LCD/LED Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/100">CRT Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/101">Laptop Replacement Screen</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/102">Monitor Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/15">System Cooling Parts</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/103">Heatsink</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/104">CPU Fans</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/105">CPU Fans / Heatsinks</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/106">Thermal Compund / Grease</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/107">Fan Tray</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/16">Cables</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/108">Network Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/109">Audio &amp; Video Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/110">KVM Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/111">Storage &amp; Data Transfer Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/112">System &amp; Power Cables</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/17">Cameras</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/113">Surveillance Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/114">Webcams</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/115">Digital Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/116">Camera Parts &amp; Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/13">More Categories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/97">Computer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/98">ICs &amp; Micro Chips</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <main class="main">
# <section class="search-div">
# <div class="container">
# <form action="#" class="input-wrapper">
# <input autocomplete="off" class="form-control search-box" name="search" oninput="fetchSuggestionsMbl(this.value)" placeholder="Search..." required="" type="text"/>
# <div class="suggestion-box-mbl" id="suggestionBoxMbl"></div>
# </form>
# </div>
# </section>
# <div class="page-content">
# <style>
#     .gradient-bg {
#         background: linear-gradient(to right, #a6f0ff, #b5a2ff);
#         padding: 30px;
#     }
#     .gradient-bg img {
#         max-width: 100%;
#         height: auto;
#     }
#     .w-80 {
#         width: 80%;
#     }
#
#     .w-20 {
#         width: 20%;
#     }
# </style>
# <div class="container mt-4">
# <div class="row g-4">
# <div class="col-lg-8 col-md-12 d-flex">
# <div class="d-flex align-items-center justify-content-between w-100 p-3">
# <img alt="Headset" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-1st.png"/>
# </div>
# </div>
# <div class="col-lg-4 col-md-6 d-flex flex-column">
# <div class="equal-height">
# <div class="col-md-12 mt-3 mt-md-0">
# <div class="d-flex align-items-center justify-content-between p-3">
# <img alt="VoIP Phone" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-2nd.png"/>
# </div>
# </div>
# <div class="col-md-12 mt-3">
# <div class="d-flex align-items-center justify-content-between p-3">
# <img alt="VoIP Phone" class="img-fluid" src="https://www.vertexnetworking.co.uk/frontend/images/home-banner-3rd.png"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <section>
# <h2 class="title title-center mt-10">Feature Brands</h2>
# <div class="code-template">
# <div class="owl-carousel owl-theme container owl-nav-full cols-lg-2 cols-md-3 cols-sm-2 cols-1 owl-nav-arrow appear-animate" data-owl-options="{
#                         'nav': false,
#                         'loop': true,
#                         'dots': true,
#                         'autoplay': true,
#                         'autoplayTimeout': 2000,
#                         'smartSpeed': 700,
#                         'items': 8,
#                         'margin': 20,
#                         'responsive': {
#                             '0': {
#                                 'items': 2
#                             },
#                             '576': {
#                                 'items': 3
#                             },
#                             '768': {
#                                 'items': 6
#                             },
#                             '992': {
#                                 'items': 8
#                             }
#                         }
#                     }">
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074611-hp.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074712-wd.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074652-ibm.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074664-toshiba.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074688-lenovo.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074631-cisco.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074640-fujitsu.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074804-samsung.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074675-kingston.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074721-ubiquiti.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074703-tp-link.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# <div class="category category-light category-absolute category-rounded overlay-zoom code-content">
# <a href="#">
# <figure class="category-media">
# <img alt="category" src="https://www.vertexnetworking.co.uk/storage/brand_images/1736074794-seagate.webp" style="width: 128px !importatn;height:128px !importatn;"/>
# </figure>
# </a>
# </div>
# </div>
# </div>
# </section>
# <section class="product-wrapper mb-10 pb-8 appear-animate grey-section" style="display: none;">
# <div class="container">
# <h2 class="title title-center mt-10">Feature Products</h2>
# <div class="toolbox">
# <div class="toolbox-left">
# <ul class="nav-filters product-filters" data-target="#products-grid">
# <li>
# <a class="nav-filter active font-weight-semi-bold" data-filter="*" href="#">All</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".1" href="#">Storage Device</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".2" href="#">Memory</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".3" href="#">Network &amp; Accessories</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".4" href="#">PC &amp; Servers</a>
# </li>
# <li>
# <a class="nav-filter font-weight-semi-bold" data-filter=".5" href="#">Softwares</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row grid products-grid mb-2" data-grid-options="{
#                 'masonry': { 'columnWidth': '' } }" id="products-grid">
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe75731c_ST900MP0006-o.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">Seagate ST900MP0006 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$179.91 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe7cbeb8_FW4KG.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">Dell FW4KG 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$92.69 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe838db7_870795-001.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">HPE 870795-001 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$297.95 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe8a770b_FXG2N.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">Dell FXG2N 2TB 7200RPM SATA 6Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$149.83 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fxg2n-dell-server-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe9194d4_870759-B21.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">HPE 870759-B21 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$290.44 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/870759-b21-hp-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe98094c_KT3WC.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">Dell KT3WC 1TB 7200RPM SATA 6Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$87.43 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/kt3wc-dell-1tb-7200rpm-sata-6gb-s-2-5-inch-hot-pluggable-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe9d1ca3_867254-003.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">HPE 867254-003 900GB 15000RPM SAS 12Gb/s 2.5-Inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$290.44 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/867254-003-hp-msa-900gb-15000rpm-sas-12gb-s-sff-2-5-inch-enterprise-hard-drive-with-tray.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-sm-4 col-6 grid-item 1" style="position: absolute; left: 0%; top: 0px;">
# <div class="product text-center">
# <figure class="product-media" style="background-color: #f9f9f9;">
# <a href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">
# <img alt="product" class="product-image" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffea45a3c_KRM6X.webp"/>
# </a>
# <div class="product-action-vertical">
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Add to cart"><i class="d-icon-bag"></i></a>
# <a class="btn-product-icon" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Add to wishlist"><i class="d-icon-heart"></i></a>
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html" title="Quick View">Quick View</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">Dell KRM6X 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price">$142.32 </ins><br/>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/krm6x-dell-4tb-7200rpm-sas-12gb-s-hot-pluggable-3-5-inch-hard-drive.html">( 8 reviews )</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section>
# <div class="container">
# <h2 class="title title-center mt-10">Feature Category</h2>
# <div class="row cols-2 cols-sm-3 cols-md-4 cols-lg-5">
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/1">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015099-rb_23945-1-2.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Storage Device</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/2">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015053-two-ram-1-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Memory</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/3">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015232-network-switch-isolated-solid-white-background-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Network &amp; Accessories</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/4">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015354-server-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">PC &amp; Servers</h4>
# </div>
# </a>
# </div>
# </div>
# <div class="category-wrap mb-4">
# <div class="category category-icon">
# <a href="https://www.vertexnetworking.co.uk/category/5">
# <figure class="categroy-media">
# <img alt="" src="https://www.vertexnetworking.co.uk/storage/category_images/1736015462-rb_2148684987-1.png"/>
# </figure>
# <div class="category-content">
# <h4 class="category-name font-weight-normal ls-normal">Softwares</h4>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="container">
# <section class="mt-10 pt-2">
# <h2 class="title title-center">Feature Products</h2>
# <div class="code-template">
# <div class="row product-wrapper equal-height">
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe75731c_ST900MP0006-o.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html" title="Quick View">Buy Now</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html">Seagate ST900MP0006 900GB 15000RPM SAS 12Gb/s 2.5-in Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price"> $179.91</ins>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/st900mp0006-seagate-enterprise-performance-15k-hdd-900gb-15000rpm-sas-12gb-s-256mb-cache-3-5-inch-hard-drive.html"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe7cbeb8_FW4KG.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# <a class="btn-product" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html" title="Quick View">Buy Now</a>
# </div>
# </figure>
# <div class="product-details">
# <div class="product-cat">
# <a href="https://www.vertexnetworking.co.uk/category/1">Storage Device</a>
# </div>
# <h3 class="product-name">
# <a href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html">Dell FW4KG 4TB 7200RPM SAS 12Gb/s 3.5-inch Hard Drive</a>
# </h3>
# <div class="product-price">
# <ins class="new-price"> $92.69</ins>
# </div>
# <div class="ratings-container">
# <div class="ratings-full">
# <span class="ratings" style="width:100%"></span>
# <span class="tooltiptext tooltip-top"></span>
# </div>
# <a class="rating-reviews" href="https://www.vertexnetworking.co.uk/product/fw4kg-dell-server-hard-drive.html"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-3 col-6">
# <div class="product product-image-gap code-content">
# <figure class="product-media">
# <a href="https://www.vertexnetworking.co.uk/product/870795-001-hp-enterprise-900gb-15000rpm-sas-12gb-s-2-5-inch-hard-drive.html">
# <img alt="product" height="315" src="https://www.vertexnetworking.co.uk/storage/product_images/6778ffe838db7_870795-001.webp" width="280"/>
# </a>
# <div class="product-action-vertical">
# </div>
# <div class="product-action">
# ...
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/41">Powerline Network Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/42">Power Over Ethernet Adapters</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/43">Network Security &amp; Firewall Devices</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/44">Terminal Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/45">IP Phones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/46">Print Servers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/4">PC &amp; Servers</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/47">Laptop PC</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/48">Laptop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/49">Workstation Systems</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/50">Workstation Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/51">Servers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/52">Server Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/53">Desktops</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/54">Desktop Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/55">Tablet PC</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/6">Motherboards</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/59">Desktop Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/60">Server Motherboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/61">Laptop Motherboards</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/7">Printers &amp; Scanners</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/62">Printers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/63">Printer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/64">Printer Cartridges</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/65">Scanner Faxes &amp; Copiers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/8">Power Equipment</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/66">Power Supplies</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/67">Power Adapters &amp; Chargers</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/68">UPS</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/69">PDUs</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/70">Surge Suppressors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/71">Power Bank</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/72">Batteries</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/73">Power Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/9">Processors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/74">Server Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/75">Desktop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/76">Laptop Processors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/77">Processor Boards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/78">VRM</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/11">Audio Components</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/84">Headphone &amp; Headsets</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/85">Microphones</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/86">Sound Cards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/87">Speakers</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/12">Input Devices</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/88">KVM Switches</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/89">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/90">Mouse</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/91">Keyboards</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/92">Input Device Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/14">Monitors</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/99">LCD/LED Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/100">CRT Monitors</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/101">Laptop Replacement Screen</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/102">Monitor Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/15">System Cooling Parts</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/103">Heatsink</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/104">CPU Fans</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/105">CPU Fans / Heatsinks</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/106">Thermal Compund / Grease</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/107">Fan Tray</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/16">Cables</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/108">Network Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/109">Audio &amp; Video Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/110">KVM Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/111">Storage &amp; Data Transfer Cables</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/112">System &amp; Power Cables</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/17">Cameras</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/113">Surveillance Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/114">Webcams</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/115">Digital Cameras</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/116">Camera Parts &amp; Accessories</a></li>
# </ul>
# </li>
# <li>
# <a href="https://www.vertexnetworking.co.uk/category/13">More Categories</a>
# <ul>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/97">Computer Accessories</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/subcategory/98">ICs &amp; Micro Chips</a></li>
# </ul>
# </li>
# <li><a href="https://www.vertexnetworking.co.uk/about-us">About US</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/contact-us">Contact US</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/login">Login</a></li>
# <li><a href="https://www.vertexnetworking.co.uk/cart">My Cart</a></li>
# </ul>
# <!-- End of MobileMenu -->
# </div>
# </div>
# <!-- Plugins JS File -->
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery/jquery.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/elevatezoom/jquery.elevatezoom.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/magnific-popup/jquery.magnific-popup.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery.floating/jquery.floating.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/owl-carousel/owl.carousel.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/imagesloaded/imagesloaded.pkgd.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/isotope/isotope.pkgd.min.js"></script>
# <!-- Main JS File -->
# <script src="https://www.vertexnetworking.co.uk/frontend/js/main.min.js"></script>
# <script src="https://www.vertexnetworking.co.uk/frontend/vendor/jquery.count-to/jquery-numerator.min.js"></script>
# <!--Start of Tawk.to Script-->
# <script type="text/javascript">
#     var Tawk_API=Tawk_API||{}, Tawk_LoadStart=new Date();
#     (function(){
#     var s1=document.createElement("script"),s0=document.getElementsByTagName("script")[0];
#     s1.async=true;
#     s1.src='https://embed.tawk.to/677c057baf5bfec1dbe76716/1igu7ar24';
#     s1.charset='UTF-8';
#     s1.setAttribute('crossorigin','*');
#     s0.parentNode.insertBefore(s1,s0);
#     })();
#     </script>
# <!--End of Tawk.to Script-->
# <script>
#         function addToCart(val)
#         {
#             // CSRF token for Laravel security
#             const csrfToken = $('meta[name="csrf-token"]').attr('content');
#             const item_qty = $('#item_qty').val();
#
#             // AJAX request
#             $.ajax({
#                 url: '/cart/add', // Replace with your route for adding to cart
#                 type: 'POST',
#                 data: {
#                     _token: csrfToken, // CSRF token for Laravel
#                     product_id: val,
#                     product_qty: item_qty,
#                 },
#                 success: function (response) {
#                     // console.log(response);
#
#                     if (response.status === 'success') {
#                         // alert('Product added to cart!');
#                         // Update cart count (optional)
#                         $('.cart-count').text(response.cart_count);
#                         $('.cart-price').text('$ '+response.cart_price);
#                     } else {
#                         alert(response.message);
#                     }
#                 },
#                 error: function (xhr, status, error) {
#                     console.error('Error adding product to cart:', xhr.responseText);
#                     alert('An error occurred while adding the product to the cart.');
#                 }
#             });
#         }
#
#         function RemoveProductFromCart(val)
#         {
#             // CSRF token for Laravel security
#             const csrfToken = $('meta[name="csrf-token"]').attr('content');
#
#             // AJAX request
#             $.ajax({
#                 url: '/cart/remove/'+val, // Replace with your route for adding to cart
#                 type: 'GET',
#                 data: {
#                     _token: csrfToken, // CSRF token for Laravel
#                 },
#                 success: function (response) {
#                     // console.log(response);
#
#                     if (response.status === 'success') {
#                         // alert('Product added to cart!');
#                         // Update cart count (optional)
#                         $('.cart-count').text(response.cart_count);
#                         $('.cart-price').text('$ '+response.cart_price);
#                         $('.summary-total-price').text('$ '+response.cart_price);
#                         const targetId = 'tr-'+val;
#                         $(`tr[data-id="${targetId}"]`).hide();
#                     } else {
#                         alert(response.message);
#                     }
#                 },
#                 error: function (xhr, status, error) {
#                     console.error('Error adding product to cart:', xhr.responseText);
#                     alert('An error occurred while adding the product to the cart.');
#                 }
#             });
#         }
#     </script>
# <script>
#         function fetchSuggestions(query) {
#             const suggestionBox = document.getElementById("suggestionBox");
#             suggestionBox.innerHTML = ""; // Clear previous suggestions
#
#             if (query.trim() === "") {
#                 suggestionBox.style.display = "none";
#                 return;
#             }
#
#             $.ajax({
#                 url: "https://www.vertexnetworking.co.uk/search-products",
#                 method: "GET",
#                 data: { query: query },
#                 success: function (response) {
#                     if (response.length > 0) {
#                         response.forEach(product => {
#                             const li = document.createElement("li");
#                             const anchor = document.createElement("a");
#                             anchor.href = `/product/${product.slug}`; // Replace with your product details route
#                             anchor.textContent = `${product.product_name}`;
#                             anchor.className = "suggestion-item";
#                             li.appendChild(anchor);
#                             suggestionBox.appendChild(li);
#                         });
#                         suggestionBox.style.display = "block";
#                     } else {
#                         const li = document.createElement("li");
#                         li.className = "no-suggestions";
#                         li.textContent = "No suggestions found";
#                         suggestionBox.appendChild(li);
#                         suggestionBox.style.display = "block";
#                     }
#                 },
#                 error: function () {
#                     const li = document.createElement("li");
#                     li.className = "no-suggestions";
#                     li.textContent = "Error fetching suggestions";
#                     suggestionBox.appendChild(li);
#                     suggestionBox.style.display = "block";
#                 }
#             });
#         }
#     </script>
# <script>
#     function fetchSuggestionsMbl(query) {
#         const suggestionBox = document.getElementById("suggestionBoxMbl");
#         suggestionBox.innerHTML = ""; // Clear previous suggestions
#
#         if (query.trim() === "") {
#             suggestionBox.style.display = "none";
#             return;
#         }
#
#         $.ajax({
#             url: "https://www.vertexnetworking.co.uk/search-products",
#             method: "GET",
#             data: { query: query },
#             success: function (response) {
#                 if (response.length > 0) {
#                     response.forEach(product => {
#                         const li = document.createElement("li");
#                         const anchor = document.createElement("a");
#                         anchor.href = `/product/${product.slug}`; // Replace with your product details route
#                         anchor.textContent = `${product.product_name}`;
#                         anchor.className = "suggestion-item";
#                         li.appendChild(anchor);
#                         suggestionBox.appendChild(li);
#                     });
#                     suggestionBox.style.display = "block";
#                 } else {
#                     const li = document.createElement("li");
#                     li.className = "no-suggestions";
#                     li.textContent = "No suggestions found";
#                     suggestionBox.appendChild(li);
#                     suggestionBox.style.display = "block";
#                 }
#             },
#             error: function () {
#                 const li = document.createElement("li");
#                 li.className = "no-suggestions";
#                 li.textContent = "Error fetching suggestions";
#                 suggestionBox.appendChild(li);
#                 suggestionBox.style.display = "block";
#             }
#         });
#     }
# </script>
# </body>
# <script>'undefined'=== typeof _trfq || (window._trfq = []);'undefined'=== typeof _trfd && (window._trfd=[]),_trfd.push({'tccl.baseHost':'secureserver.net'},{'ap':'cpbh-mt'},{'server':'sxb1plmcpnl480540'},{'dcenter':'sxb1'},{'cp_id':'10221597'},{'cp_cl':'8'}) // Monitoring performance to make your website faster. If you want to opt-out, please contact web hosting support.</script><script src="https://img1.wsimg.com/traffic-assets/js/tccl.min.js"></script></html>
# >

# %%
soup.find_all("h1")[0].text
# Out:
# 'Programs Offered  By Minhaj University Lahore'

# %%
len(soup.find_all("h2"))
# Out:
# 1

# %%
soup.find_all("a")
# Out:
# [<a class="logo-dark" href="https://www.mul.edu.pk/en/">
#  <img alt="mul-logo" class="img-fluid" src="https://www.mul.edu.pk/images/mul_logo.jpg" style="width: 170px;"/>
#  </a>,
#  <a class="logo-light" href="https://www.mul.edu.pk/en/">
#  <img alt="mul-logo" class="img-fluid" src="https://www.mul.edu.pk/images/mul_logo.jpg" style="width: 170px;"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/">Home</a>,
#  <a href="#">About </a>,
#  <a href="#"> Leadership &amp; <br/> Governance</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/welcome-from-the-chairman-board-of-governors-bog"> Chairman</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/message-from-the-deputy-chairman-bog"> Deputy Chairman</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/message-from-the-vice-chancellor"> Vice Chancellor</a>,
#  <a href="https://www.mul.edu.pk/en/deans"> Deans</a>,
#  <a href="https://www.mul.edu.pk/en/directors"> Directors</a>,
#  <a href="https://www.mul.edu.pk/en/hods"> Head of Schools</a>,
#  <a href="https://www.mul.edu.pk/en/bogs"> Board of Governors</a>,
#  <a href="https://www.mul.edu.pk/en/academic-council"> Academic Council</a>,
#  <a href="#"> Officers of MUL</a>,
#  <a href="https://www.mul.edu.pk/en/office-of-registrar"> Office of the Registrar</a>,
#  <a href="https://www.mul.edu.pk/en/about"> About MUL</a>,
#  <a href="https://www.mul.edu.pk/en/mul-at-glance"> MUL at a Glance</a>,
#  <a href="https://dgl.mul.edu.pk/" target="_blank"> Global Linkages</a>,
#  <a href="https://www.mul.edu.pk/en/news-events">News &amp; Events</a>,
#  <a href="#">Admissions </a>,
#  <a href="https://www.mul.edu.pk/en/programs"> All Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/bs-programs"> BS Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/mphil-programs"> M.Phil Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/phd-programs"> Ph.D. Programs</a>,
#  <a href="https://www.mul.edu.pk/en/fee-calculator"> Fee Calculator</a>,
#  <a href="https://www.mul.edu.pk/en/scholarships-and-fee-concession"> Financial Aids &amp; Scholarships</a>,
#  <a href="https://www.mul.edu.pk/en/admission-guide"> Admission Guide</a>,
#  <a href="https://www.mul.edu.pk/en/admission-policy"> Admission Policy</a>,
#  <a href="https://www.mul.edu.pk/downloads/MUL_Prospectus.pdf"> Prospectus</a>,
#  <a href="https://admission.mul.edu.pk/"> Apply Now</a>,
#  <a href="https://www.mul.edu.pk/en/contact">Contact</a>,
#  <a href="#">Academics </a>,
#  <a href="#"> Faculties</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/health-sciences"> Faculty of Allied Health Sciences</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/applied-sciences"> Faculty of Applied Sciences</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/art-designing-and-architecture"> Faculty of Art, Designing, &amp; Architecture</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/basic-sciences-and-mathematics"> Faculty of Basic Sciences &amp; Mathematics</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/computer-science-and-information-technology"> Faculty of Computer Science &amp; Information Technology</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/economics-and-management-science"> Faculty of Economics &amp; Management Sciences</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/engineering"> Faculty of Engineering</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/islamic-studies"> Faculty of Islamic Studies</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/languages"> Faculty of Languages</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/law"> Faculty of Law</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/pharmacy"> Faculty of Pharmacy</a>,
#  <a href="https://www.mul.edu.pk/en/faculty/social-sciences-and-humanities"> Faculty of Social Sciences &amp; Humanities</a>,
#  <a href="https://www.mul.edu.pk/en/adjunct-faculty"> Adjunct Faculty</a>,
#  <a href="https://www.mul.edu.pk/en/academic-advisement"> Academic Advisement</a>,
#  <a href="https://www.mul.edu.pk/en/academic-calendar"> Academic Calendar</a>,
#  <a href="https://www.mul.edu.pk/downloads/rules-and-regulations.pdf" target="_blank"> Rules &amp; Regulations</a>,
#  <a href="#">Research</a>,
#  <a href="https://www.mul.edu.pk/en/research-centers/"> Research Centers</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/center-for-research-and-development"> Center for Research and Development</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/center-of-islamic-arts-and-crafts"> Center of Islamic Arts and Crafts </a>,
#  <a href="https://www.mul.edu.pk/en/news-events/centre-for-economic-planning-and-development-cepd"> Centre for Economic Planning and Development (CEPD)</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/centre-for-halal-awareness-research-and-training"> Centre for Halal Awareness, Research and Training</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/centre-of-research-and-innovation-in-maritime-affairs"> Centre of Research and Innovation in Maritime Affairs </a>,
#  <a href="https://www.mul.edu.pk/en/news-events/corpus-research-centre"> Corpus Research Centre</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/directorate-of-open-and-distance-learning-dodl"> Directorate of Open and Distance Learning (DODL)</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/english-language-center"> English Language Center</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/farid-e-millat-research-institute"> Farid-e-Millat Research Institute</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/hassan-bin-thabit-center-for-research-in-nat-literature"> Hassan-bin-Thabit Center for Research in Na’t Literature</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/international-center-for-research-in-islamic-economics"> International Center for Research in Islamic Economics</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/international-center-of-excellence"> International Center of Excellence</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/office-of-research-innovation-commercialization"> Office of Research, Innovation &amp; Commercialization</a>,
#  <a href="https://www.mul.edu.pk/en/news-events/shaykh-ul-islam-institute-of-spiritual-studies"> Shaykh ul Islam Institute of Spiritual Studies</a>,
#  <a href="https://www.mul.edu.pk/en/journals/">Research Journals</a>,
#  <a href="https://www.mul.edu.pk/en/conferences/">Conferences</a>,
#  <a href="https://www.mul.edu.pk/en/publications/">Publications</a>,
#  <a href="#"> Policies</a>,
#  <a href="https://www.mul.edu.pk/downloads/pitman_proposal.pdf" target="_blank"> Pitman Proposal</a>,
#  <a href="https://www.mul.edu.pk/downloads/plagiarism_policy.pdf" target="_blank"> Plagiarism Policy</a>,
#  <a href="https://www.mul.edu.pk/downloads/research_proposal.pdf" target="_blank"> Research Proposal</a>,
#  <a href="#">Campus Life</a>,
#  <a href="https://www.mul.edu.pk/en/students-perspectives" style="text-transform: none !important;"> Student`s Perspective</a>,
#  <a href="https://www.mul.edu.pk/en/campus-facilities" style="text-transform: none !important;"> Campus Facilities</a>,
#  <a href="https://www.mul.edu.pk/en/seekers-club" style="text-transform: none !important;"> Seekers Club &amp; Societies</a>,
#  <a href="https://www.mul.edu.pk/en/campus-tour" style="text-transform: none !important;"> Campus Tour</a>,
#  <a href="https://minhaj.rozee.pk/" target="_blank">MUL Jobs Employment Portal</a>,
#  <a href="https://www.mul.edu.pk/en/downloads">Downloads</a>,
#  <a href="https://career.mul.edu.pk">Career</a>,
#  <a href="tel:+9242351456219"><span>(+92) 42 35145621-9</span></a>,
#  <a href="tel:+923111181685"><span>03 111 222 685</span></a>,
#  <a href="#"><span class="__cf_email__" data-cfemail="147d7a727b54716c75796478717379757d783a777b79">info@mul.edu.pk</span></a>,
#  <a href="#"><span class="__cf_email__" data-cfemail="147d7a727b54716c75796478717379757d783a777b79">admission@mul.edu.pk</span></a>,
#  <a href="tel:+923111181685"><span>Let`s Talk with Admissions Representative</span></a>,
#  <a href="https://twitter.com/OfficialMUL" target="_blank"><i class="bi bi-twitter-x"></i></a>,
#  <a href="https://www.instagram.com/minhajuniversitylahore/" target="_blank"><i class="bi bi-instagram"></i></a>,
#  <a href="https://linkedin.com/company/minhajuniversitylahore" target="_blank"><i class="bi bi-linkedin"></i></a>,
#  <a href="https://www.facebook.com/MinhajUniversityLahore" target="_blank"><i class="bi bi-facebook"></i></a>,
#  <a href="https://www.youtube.com/c/MinhajUniversityLahore-Official" target="_blank"><i class="bi bi-youtube"></i></a>,
#  <a href="https://whatsapp.com/channel/0029VaEs5tRAjPXHCUUdTB2p" target="_blank"><i class="bi bi-whatsapp"></i></a>,
#  <a class="logo-dark" href="https://www.mul.edu.pk/en/">
#  <img alt="mul-logo" class="img-fluid" src="https://www.mul.edu.pk/images/logo-mul-footer.png" style="width: 200px;"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/" style="color: white;">Home</a>,
#  <a class="drop-down" href="#" style="color: white;">About</a>,
#  <a href="#">Leaderhsip and Governance</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/welcome-from-the-chairman-board-of-governors-bog"> Chairman</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/message-from-the-deputy-chairman-bog"> Deputy Chairman</a>,
#  <a href="https://www.mul.edu.pk/en/welcome-message/message-from-the-vice-chancellor"> Vice Chancellor</a>,
#  <a href="https://www.mul.edu.pk/en/deans"> Deans</a>,
#  <a href="https://www.mul.edu.pk/en/directors"> Directors</a>,
#  <a href="https://www.mul.edu.pk/en/hods"> Heads of Schools</a>,
#  <a href="https://www.mul.edu.pk/en/bogs"> Board of Governors</a>,
#  <a href="https://www.mul.edu.pk/en/academic-council"> Academic Council</a>,
#  <a href="#">Officers of MUL</a>,
#  <a href="https://www.mul.edu.pk/en/office-of-registrar"> Office of the Registrar</a>,
#  <a href="https://www.mul.edu.pk/en/about"> About MUL</a>,
#  <a href="https://www.mul.edu.pk/en/mul-at-glance"> MUL at a Glance</a>,
#  <a href="https://dgl.mul.edu.pk/" target="_blank"> Global Linkages</a>,
#  <a href="https://www.mul.edu.pk/en/news-events" style="color: white;">News &amp; Events</a>,
#  <a class="drop-down" href="#" style="color: white;">Admissions</a>,
#  <a href="https://www.mul.edu.pk/en/programs"> All Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/bs-programs"> BS Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/mphil-programs"> M.Phil Programs</a>,
#  <a href="https://www.mul.edu.pk/en/programs/phd-programs"> Ph.D. Programs</a>,
#  <a href="https://www.mul.edu.pk/en/fee-calculator"> Fee Calculator</a>,
#  <a href="https://www.mul.edu.pk/en/scholarships-and-fee-concession"> Financial Aids &amp; Scholarships</a>,
#  <a href="https://www.mul.edu.pk/en/admission-guide"> Admission Guide</a>,
#  <a href="https://www.mul.edu.pk/en/admission-policy"> Admission Policy</a>,
#  <a href="https://www.mul.edu.pk/downloads/MUL_Prospectus.pdf" target="_blank"> Prospectus</a>,
#  <a href="https://admission.mul.edu.pk/"> Apply Now</a>,
#  <a href="https://www.mul.edu.pk/en/contact" style="color: white;">Contact</a>,
#  <a class="primary-btn4 d-xl-flex d-none" href="https://admission.mul.edu.pk" target="_blank">
#                          Apply Now
#                      </a>,
#  <a href="https://api.whatsapp.com/send?phone=923111181685" target="_blank">
#  <svg fill="currentColor" height="20" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg">
#  <path d="M12 0C5.372 0 0 5.373 0 12c0 2.123.555 4.196 1.607 6.025L0 24l6.184-1.607A11.94 11.94 0 0 0 12 24c6.627 0 12-5.373 12-12S18.627 0 12 0zm0 21.818a9.82 9.82 0 0 1-5.001-1.373l-.357-.212-3.669.955.98-3.576-.232-.369A9.79 9.79 0 1 1 12 21.818zm5.4-7.232c-.294-.147-1.736-.857-2.005-.955-.269-.098-.465-.147-.662.147-.196.294-.759.955-.931 1.151-.172.196-.343.221-.637.074-.294-.147-1.24-.457-2.363-1.458-.874-.78-1.464-1.743-1.636-2.037-.172-.294-.018-.453.129-.6.132-.131.294-.343.441-.515.147-.172.196-.294.294-.49.098-.196.049-.368-.025-.515-.074-.147-.662-1.594-.907-2.183-.239-.575-.482-.497-.662-.506h-.565c-.196 0-.515.074-.784.368s-1.03 1.005-1.03 2.45 1.055 2.84 1.202 3.037c.147.196 2.077 3.174 5.033 4.45.704.304 1.253.486 1.68.621.705.224 1.347.192 1.854.116.566-.085 1.736-.709 1.98-1.392.245-.683.245-1.27.172-1.392-.073-.123-.269-.196-.564-.343z"></path>
#  </svg>
#  <span><strong>Admissions Chat</strong></span>
#  </a>,
#  <a href="https://web.whatsapp.com/send?phone=923111181685" target="_blank">
#  <svg fill="currentColor" height="20" viewbox="0 0 24 24" width="20" xmlns="http://www.w3.org/2000/svg">
#  <path d="M12 0C5.372 0 0 5.373 0 12c0 2.123.555 4.196 1.607 6.025L0 24l6.184-1.607A11.94 11.94 0 0 0 12 24c6.627 0 12-5.373 12-12S18.627 0 12 0zm0 21.818a9.82 9.82 0 0 1-5.001-1.373l-.357-.212-3.669.955.98-3.576-.232-.369A9.79 9.79 0 1 1 12 21.818zm5.4-7.232c-.294-.147-1.736-.857-2.005-.955-.269-.098-.465-.147-.662.147-.196.294-.759.955-.931 1.151-.172.196-.343.221-.637.074-.294-.147-1.24-.457-2.363-1.458-.874-.78-1.464-1.743-1.636-2.037-.172-.294-.018-.453.129-.6.132-.131.294-.343.441-.515.147-.172.196-.294.294-.49.098-.196.049-.368-.025-.515-.074-.147-.662-1.594-.907-2.183-.239-.575-.482-.497-.662-.506h-.565c-.196 0-.515.074-.784.368s-1.03 1.005-1.03 2.45 1.055 2.84 1.202 3.037c.147.196 2.077 3.174 5.033 4.45.704.304 1.253.486 1.68.621.705.224 1.347.192 1.854.116.566-.085 1.736-.709 1.98-1.392.245-.683.245-1.27.172-1.392-.073-.123-.269-.196-.564-.343z"></path>
#  </svg>
#  <span><strong>Admissions Chat</strong></span>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/call-me-back" style="color: white; writing-mode: vertical-rl; text-decoration: none; font-size: 14px;">
#  <b>Call me Back</b>
#  </a>,
#  <a href="/">Home</a>,
#  <a href="#adp">AD Programs</a>,
#  <a href="#bs">BS Programs</a>,
#  <a href="#mphil">M.Phil Programs</a>,
#  <a href="#phd">Ph.D. Programs</a>,
#  <a href="#short_courses">Short Courses</a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics">
#  <img alt="BS Human Nutrition and Dietetics" src="https://www.mul.edu.pk/images/programs/bs-human-nutrition-and-dietetics_245.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics">BS Human Nutrition and Dietetics</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences">
#  <img alt="BS Criminology and Forensic Sciences" src="https://www.mul.edu.pk/images/programs/bs-criminology-and-forensic-sciences_281.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences">BS Criminology and Forensic Sciences</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-digital-marketing">
#  <img alt="BS Digital Marketing" src="https://www.mul.edu.pk/images/programs/bs-digital-marketing_286.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-digital-marketing">BS Digital Marketing</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-digital-marketing"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-e-commerce">
#  <img alt="BS E-Commerce" src="https://www.mul.edu.pk/images/programs/bs-e-commerce_302.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-e-commerce">BS E-Commerce</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-e-commerce"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication">
#  <img alt="BS in Digital Media Communication" src="https://www.mul.edu.pk/images/programs/bs-in-digital-media-communication_311.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication">BS in Digital Media Communication</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation">
#  <img alt="BS in Multimedia Arts- Animation" src="https://www.mul.edu.pk/images/programs/bs-in-multimedia-arts_312.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation">BS in Multimedia Arts- Animation</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology">
#  <img alt="Bachelor of Science in Financial Technology" src="https://www.mul.edu.pk/images/programs/bachelor-of-science-in-financial-technology_338.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology">Bachelor of Science in Financial Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science">
#  <img alt="BS Economics and Data Science" src="https://www.mul.edu.pk/images/programs/bs-economics-and-data-science_353.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science">BS Economics and Data Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-statistics-data-science">
#  <img alt="BS Statistics &amp; Data Science" src="https://www.mul.edu.pk/images/programs/bs-statistics-data-science_358.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-statistics-data-science">BS Statistics &amp; Data Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-statistics-data-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences">
#  <img alt="BS Computational Plant Sciences" src="https://www.mul.edu.pk/images/programs/bs-computational-plant-sciences_357.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences">BS Computational Plant Sciences</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship">
#  <img alt="BS Chemistry &amp;  Industrial Entrepreneurship" src="https://www.mul.edu.pk/images/programs/bs-chemistry-industrial-entrepreneurship_356.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship">BS Chemistry &amp;  Industrial Entrepreneurship</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management">
#  <img alt="BS Information System &amp; Technology Management" src="https://www.mul.edu.pk/images/programs/bs-information-system-technology-management_361.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management">BS Information System &amp; Technology Management</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology">
#  <img alt=" BS Zoology and Entomology" src="https://www.mul.edu.pk/images/programs/bs-zoology-and-entomology_362.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology"> BS Zoology and Entomology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology">
#  <img alt="BS Islamic Banking &amp;  Financial Technology" src="https://www.mul.edu.pk/images/programs/bs-islamic-banking-financial-technology_366.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology">BS Islamic Banking &amp;  Financial Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-management">
#  <img alt="BS Information Management" src="https://www.mul.edu.pk/images/programs/bs-information-management_365.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-management">BS Information Management</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-management"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science">
#  <img alt="BS Mathematics &amp; Data Science" src="https://www.mul.edu.pk/images/programs/bs-mathematics-data-science_367.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science">BS Mathematics &amp; Data Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies">
#  <img alt="BS Defense and Strategic Studies" src="https://www.mul.edu.pk/images/programs/bs-defense-and-strategic-studies_371.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies">BS Defense and Strategic Studies</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years">
#  <img alt="Bachelor of Laws (LLB) 4 years" src="https://www.mul.edu.pk/images/programs/bachelor-of-laws-llb-4-years_491.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years">Bachelor of Laws (LLB) 4 years</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-business-analytics">
#  <img alt="BS Business Analytics" src="https://www.mul.edu.pk/images/programs/bs-business-analytics_492.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-business-analytics">BS Business Analytics</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-business-analytics"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-psychology">
#  <img alt="BS Psychology" src="https://www.mul.edu.pk/images/programs/bs-psychology_507.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-psychology">BS Psychology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-psychology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology">
#  <img alt="BS Aesthetics and Cosmetology" src="https://www.mul.edu.pk/images/programs/bs-aesthetics-and-cosmetology_515.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology">BS Aesthetics and Cosmetology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-computer-science">
#  <img alt="BS Computer Science" src="https://www.mul.edu.pk/images/programs/bs-computer-science_1.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-computer-science">BS Computer Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-computer-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy">
#  <img alt="Doctor of Pharmacy" src="https://www.mul.edu.pk/images/programs/doctor-of-pharmacy_256.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy">Doctor of Pharmacy</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-technology">
#  <img alt="BS Information Technology" src="https://www.mul.edu.pk/images/programs/bs-information-technology_2.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-information-technology">BS Information Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-software-engineering">
#  <img alt="BS Software Engineering" src="https://www.mul.edu.pk/images/programs/bs-software-engineering_9.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-software-engineering">BS Software Engineering</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-software-engineering"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence">
#  <img alt="BS Artificial Intelligence" src="https://www.mul.edu.pk/images/programs/bs-artificial-intelligence_240.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence">BS Artificial Intelligence</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-cyber-security">
#  <img alt="BS Cyber Security" src="https://www.mul.edu.pk/images/programs/bs-cyber-security_241.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-cyber-security">BS Cyber Security</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-cyber-security"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bba">
#  <img alt="BBA" src="https://www.mul.edu.pk/images/programs/bba_4.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bba">BBA</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bba"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-education">
#  <img alt="BS Education" src="https://www.mul.edu.pk/images/programs/bs-education_155.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-education">BS Education</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-education"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-biotechnology">
#  <img alt="BS Biotechnology" src="https://www.mul.edu.pk/images/programs/bs-biotechnology_243.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-biotechnology">BS Biotechnology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-biotechnology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-data-science">
#  <img alt="BS Data Science" src="https://www.mul.edu.pk/images/programs/bs-data-science_292.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-data-science">BS Data Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-data-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-english">
#  <img alt="BS English" src="https://www.mul.edu.pk/images/programs/bs_10.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-english">BS English</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-english"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-political-science">
#  <img alt="BS Political Science" src="https://www.mul.edu.pk/images/programs/bs-political-science_13.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-political-science">BS Political Science</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-political-science"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-international-relations">
#  <img alt="BS International Relations" src="https://www.mul.edu.pk/images/programs/bs-international-relations_14.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-international-relations">BS International Relations</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-international-relations"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology">
#  <img alt="BS Medical Laboratory Technology" src="https://www.mul.edu.pk/images/programs/bs-medical-laboratory-technology_24.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology">BS Medical Laboratory Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-food-science-technology">
#  <img alt="BS Food Science &amp; Technology" src="https://www.mul.edu.pk/images/programs/bs-food-science-technology_166.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-food-science-technology">BS Food Science &amp; Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-food-science-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics">
#  <img alt="BS Economics" src="https://www.mul.edu.pk/images/programs/bs-economics_64.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics">BS Economics</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology">
#  <img alt="BS Economics and Financial Technology" src="https://www.mul.edu.pk/images/programs/bs-economics-and-financial-technology_66.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology">BS Economics and Financial Technology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance">
#  <img alt="BS Islamic Banking &amp; Finance" src="https://www.mul.edu.pk/images/programs/bs-islamic-banking-finance_71.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance">BS Islamic Banking &amp; Finance</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bcom-4-year">
#  <img alt="B.Com (4 Year)" src="https://www.mul.edu.pk/images/programs/bcom-4-year_92.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bcom-4-year">B.Com (4 Year)</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bcom-4-year"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance">
#  <img alt="BS Accounting and Finance" src="https://www.mul.edu.pk/images/programs/bs-accounting-and-finance_93.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance">BS Accounting and Finance</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-sociology">
#  <img alt="BS Sociology" src="https://www.mul.edu.pk/images/programs/bs-sociology_121.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-sociology">BS Sociology</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-sociology"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering">
#  <img alt="B.Sc. Chemical Engineering" src="https://www.mul.edu.pk/images/programs/bsc-chemical-engineering_130.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering">B.Sc. Chemical Engineering</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering">
#  <img alt="B.Sc. Electrical Engineering" src="https://www.mul.edu.pk/images/programs/bsc-electrical-engineering_135.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering">B.Sc. Electrical Engineering</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-biochemistry">
#  <img alt="BS Biochemistry" src="https://www.mul.edu.pk/images/programs/bs-biochemistry_172.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-biochemistry">BS Biochemistry</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-biochemistry"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies">
#  <img alt="BS Peace and Conflict Studies" src="https://www.mul.edu.pk/images/programs/bs-peace-and-conflict-studies_180.jpg"/>
#  </a>,
#  <a href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies">BS Peace and Conflict Studies</a>,
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies"> Find Out More <i class="feather-arrow-right"></i></a>,
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>,
#  <a href="#">
#  <img alt="Minhaj University Lahore" src="https://www.mul.edu.pk/images/logo-mul-footer.png" width="250px"/>
#  </a>,
#  <a href="https://twitter.com/OfficialMUL" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-twitter-x"></i></a>,
#  <a href="https://www.instagram.com/minhajuniversitylahore/" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-instagram"></i></a>,
#  <a href="https://linkedin.com/company/minhajuniversitylahore" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-linkedin"></i></a>,
#  <a href="https://www.facebook.com/MinhajUniversityLahore" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-facebook"></i></a>,
#  <a href="https://www.youtube.com/c/MinhajUniversityLahore-Official" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-youtube"></i></a>,
#  <a href="https://whatsapp.com/channel/0029VaEs5tRAjPXHCUUdTB2p" style="color: white; font-size: 25px;" target="_blank"><i class="bi bi-whatsapp"></i></a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/admissions-open" target="_blank">Admissions</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/programs" target="_blank">Programs</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/scholarships-and-fee-concession" target="_blank">Scholarships &amp; Financial Aids</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/campus-facilities/" target="_blank">Campus Facilities</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/campus-tour/" target="_blank">Campus Tour</a>,
#  <a class="text-white" href="https://cms.mul.edu.pk/" target="_blank">CMS Login</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/research-centers" target="_blank">Research Centers</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/research-labs" target="_blank">Research Labs</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/publications" target="_blank">Publications</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/news-events" target="_blank">Research News</a>,
#  <a class="text-white" href="tel:+9242351456219">(+92) 42 35145621-9</a>,
#  <a class="text-white" href="tel:03 111 222 685">03 111 222 685</a>,
#  <a class="text-white" href="mailto:info@mul.edu.pk">info@mul.edu.pk</a>,
#  <a href="https://get.mul.edu.pk/?os=android&amp;med=d1befa03c79ca0b84ecc488dea96bc68" style="color: white;" target="_blank">
#  <i class="fab fa-android"></i>
#  </a>,
#  <a href="https://get.mul.edu.pk/?os=ios&amp;med=d1befa03c79ca0b84ecc488dea96bc68" style="color: white;" target="_blank">
#  <i class="fab fa-apple"></i>
#  </a>,
#  <a class="text-white" href="#">Minhaj University Lahore</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/admission-policy">Admission Policy</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/downloads/rules-and-regulations.pdf" target="_blank">Rules &amp; Regulations</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/downloads">Downloads</a>,
#  <a class="text-white" href="https://career.mul.edu.pk/" target="_blank">Career</a>,
#  <a class="text-white" href="https://www.mul.edu.pk/en/privacy-policy" target="_blank">Privacy Policy</a>]

# %%
for i in soup.find_all("a"):
    print(i.text.strip())
# Out:
# Home
# About
# Leadership &  Governance
# Chairman
# Deputy Chairman
# Vice Chancellor
# Deans
# Directors
# Head of Schools
# Board of Governors
# Academic Council
# Officers of MUL
# Office of the Registrar
# About MUL
# MUL at a Glance
# Global Linkages
# News & Events
# Admissions
# All Programs
# BS Programs
# M.Phil Programs
# Ph.D. Programs
# Fee Calculator
# Financial Aids & Scholarships
# Admission Guide
# Admission Policy
# Prospectus
# Apply Now
# Contact
# Academics
# Faculties
# Faculty of Allied Health Sciences
# Faculty of Applied Sciences
# Faculty of Art, Designing, & Architecture
# Faculty of Basic Sciences & Mathematics
# Faculty of Computer Science & Information Technology
# Faculty of Economics & Management Sciences
# Faculty of Engineering
# Faculty of Islamic Studies
# Faculty of Languages
# Faculty of Law
# Faculty of Pharmacy
# Faculty of Social Sciences & Humanities
# Adjunct Faculty
# Academic Advisement
# Academic Calendar
# Rules & Regulations
# Research
# Research Centers
# Center for Research and Development
# Center of Islamic Arts and Crafts
# Centre for Economic Planning and Development (CEPD)
# Centre for Halal Awareness, Research and Training
# Centre of Research and Innovation in Maritime Affairs
# Corpus Research Centre
# Directorate of Open and Distance Learning (DODL)
# English Language Center
# Farid-e-Millat Research Institute
# Hassan-bin-Thabit Center for Research in Na’t Literature
# International Center for Research in Islamic Economics
# International Center of Excellence
# Office of Research, Innovation & Commercialization
# Shaykh ul Islam Institute of Spiritual Studies
# Research Journals
# Conferences
# Publications
# Policies
# Pitman Proposal
# Plagiarism Policy
# Research Proposal
# Campus Life
# Student`s Perspective
# Campus Facilities
# Seekers Club & Societies
# Campus Tour
# MUL Jobs Employment Portal
# Downloads
# Career
# (+92) 42 35145621-9
# 03 111 222 685
# info@mul.edu.pk
# admission@mul.edu.pk
# Let`s Talk with Admissions Representative
#
#
#
#
#
#
#
# Home
# About
# Leaderhsip and Governance
# Chairman
# Deputy Chairman
# Vice Chancellor
# Deans
# Directors
# Heads of Schools
# Board of Governors
# Academic Council
# Officers of MUL
# Office of the Registrar
# About MUL
# MUL at a Glance
# Global Linkages
# News & Events
# Admissions
# All Programs
# BS Programs
# M.Phil Programs
# Ph.D. Programs
# Fee Calculator
# Financial Aids & Scholarships
# Admission Guide
# Admission Policy
# Prospectus
# Apply Now
# Contact
# Apply Now
# Admissions Chat
# Admissions Chat
# Call me Back
# Home
# AD Programs
# BS Programs
# M.Phil Programs
# Ph.D. Programs
# Short Courses
#
# BS Human Nutrition and Dietetics
# Find Out More
# Apply Now
#
# BS Criminology and Forensic Sciences
# Find Out More
# Apply Now
#
# BS Digital Marketing
# Find Out More
# Apply Now
#
# BS E-Commerce
# Find Out More
# Apply Now
#
# BS in Digital Media Communication
# Find Out More
# Apply Now
#
# BS in Multimedia Arts- Animation
# Find Out More
# Apply Now
#
# Bachelor of Science in Financial Technology
# Find Out More
# Apply Now
#
# BS Economics and Data Science
# Find Out More
# Apply Now
#
# BS Statistics & Data Science
# Find Out More
# Apply Now
#
# BS Computational Plant Sciences
# Find Out More
# Apply Now
#
# BS Chemistry &  Industrial Entrepreneurship
# Find Out More
# Apply Now
#
# BS Information System & Technology Management
# Find Out More
# Apply Now
#
# BS Zoology and Entomology
# Find Out More
# Apply Now
#
# BS Islamic Banking &  Financial Technology
# Find Out More
# Apply Now
#
# BS Information Management
# Find Out More
# Apply Now
#
# BS Mathematics & Data Science
# Find Out More
# Apply Now
#
# BS Defense and Strategic Studies
# Find Out More
# Apply Now
#
# Bachelor of Laws (LLB) 4 years
# Find Out More
# Apply Now
#
# BS Business Analytics
# Find Out More
# Apply Now
#
# BS Psychology
# Find Out More
# Apply Now
#
# BS Aesthetics and Cosmetology
# Find Out More
# Apply Now
#
# BS Computer Science
# Find Out More
# Apply Now
#
# Doctor of Pharmacy
# Find Out More
# Apply Now
#
# BS Information Technology
# Find Out More
# Apply Now
#
# BS Software Engineering
# Find Out More
# Apply Now
#
# BS Artificial Intelligence
# Find Out More
# Apply Now
#
# BS Cyber Security
# Find Out More
# Apply Now
#
# BBA
# Find Out More
# Apply Now
#
# BS Education
# Find Out More
# Apply Now
#
# BS Biotechnology
# Find Out More
# Apply Now
#
# BS Data Science
# Find Out More
# Apply Now
#
# BS English
# Find Out More
# Apply Now
#
# BS Political Science
# Find Out More
# Apply Now
#
# BS International Relations
# Find Out More
# Apply Now
#
# BS Medical Laboratory Technology
# Find Out More
# Apply Now
#
# BS Food Science & Technology
# Find Out More
# Apply Now
#
# BS Economics
# Find Out More
# Apply Now
#
# BS Economics and Financial Technology
# Find Out More
# Apply Now
#
# BS Islamic Banking & Finance
# Find Out More
# Apply Now
#
# B.Com (4 Year)
# Find Out More
# Apply Now
#
# BS Accounting and Finance
# Find Out More
# Apply Now
#
# BS Sociology
# Find Out More
# Apply Now
#
# B.Sc. Chemical Engineering
# Find Out More
# Apply Now
#
# B.Sc. Electrical Engineering
# Find Out More
# Apply Now
#
# BS Biochemistry
# Find Out More
# Apply Now
#
# BS Peace and Conflict Studies
# Find Out More
# Apply Now
#
#
#
#
#
#
#
# Admissions
# Programs
# Scholarships & Financial Aids
# Campus Facilities
# Campus Tour
# CMS Login
# Research Centers
# Research Labs
# Publications
# Research News
# (+92) 42 35145621-9
# 03 111 222 685
# info@mul.edu.pk
#
#
# Minhaj University Lahore
# Admission Policy
# Rules & Regulations
# Downloads
# Career
# Privacy Policy

# %%
main = soup.find_all('div', class_='rbt-card-img')

# %%
soup.find_all("div", class_="maso-item")
# Out:
# [<div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics">
#  <img alt="BS Human Nutrition and Dietetics" src="https://www.mul.edu.pk/images/programs/bs-human-nutrition-and-dietetics_245.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics">BS Human Nutrition and Dietetics</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences">
#  <img alt="BS Criminology and Forensic Sciences" src="https://www.mul.edu.pk/images/programs/bs-criminology-and-forensic-sciences_281.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences">BS Criminology and Forensic Sciences</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-criminology-and-forensic-sciences"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-digital-marketing">
#  <img alt="BS Digital Marketing" src="https://www.mul.edu.pk/images/programs/bs-digital-marketing_286.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-digital-marketing">BS Digital Marketing</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-digital-marketing"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-e-commerce">
#  <img alt="BS E-Commerce" src="https://www.mul.edu.pk/images/programs/bs-e-commerce_302.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-e-commerce">BS E-Commerce</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-e-commerce"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication">
#  <img alt="BS in Digital Media Communication" src="https://www.mul.edu.pk/images/programs/bs-in-digital-media-communication_311.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication">BS in Digital Media Communication</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-in-digital-media-communication"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation">
#  <img alt="BS in Multimedia Arts- Animation" src="https://www.mul.edu.pk/images/programs/bs-in-multimedia-arts_312.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation">BS in Multimedia Arts- Animation</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-in-multimedia-arts-animation"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology">
#  <img alt="Bachelor of Science in Financial Technology" src="https://www.mul.edu.pk/images/programs/bachelor-of-science-in-financial-technology_338.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology">Bachelor of Science in Financial Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bachelor-of-science-in-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science">
#  <img alt="BS Economics and Data Science" src="https://www.mul.edu.pk/images/programs/bs-economics-and-data-science_353.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science">BS Economics and Data Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics-and-data-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-statistics-data-science">
#  <img alt="BS Statistics &amp; Data Science" src="https://www.mul.edu.pk/images/programs/bs-statistics-data-science_358.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-statistics-data-science">BS Statistics &amp; Data Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-statistics-data-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences">
#  <img alt="BS Computational Plant Sciences" src="https://www.mul.edu.pk/images/programs/bs-computational-plant-sciences_357.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences">BS Computational Plant Sciences</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-computational-plant-sciences"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship">
#  <img alt="BS Chemistry &amp;  Industrial Entrepreneurship" src="https://www.mul.edu.pk/images/programs/bs-chemistry-industrial-entrepreneurship_356.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship">BS Chemistry &amp;  Industrial Entrepreneurship</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-chemistry-industrial-entrepreneurship"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management">
#  <img alt="BS Information System &amp; Technology Management" src="https://www.mul.edu.pk/images/programs/bs-information-system-technology-management_361.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management">BS Information System &amp; Technology Management</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-system-technology-management"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology">
#  <img alt=" BS Zoology and Entomology" src="https://www.mul.edu.pk/images/programs/bs-zoology-and-entomology_362.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology"> BS Zoology and Entomology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-zoology-and-entomology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology">
#  <img alt="BS Islamic Banking &amp;  Financial Technology" src="https://www.mul.edu.pk/images/programs/bs-islamic-banking-financial-technology_366.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology">BS Islamic Banking &amp;  Financial Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-islamic-banking-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-information-management">
#  <img alt="BS Information Management" src="https://www.mul.edu.pk/images/programs/bs-information-management_365.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-information-management">BS Information Management</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-management"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science">
#  <img alt="BS Mathematics &amp; Data Science" src="https://www.mul.edu.pk/images/programs/bs-mathematics-data-science_367.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science">BS Mathematics &amp; Data Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-mathematics-data-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies">
#  <img alt="BS Defense and Strategic Studies" src="https://www.mul.edu.pk/images/programs/bs-defense-and-strategic-studies_371.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies">BS Defense and Strategic Studies</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-defense-and-strategic-studies"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years">
#  <img alt="Bachelor of Laws (LLB) 4 years" src="https://www.mul.edu.pk/images/programs/bachelor-of-laws-llb-4-years_491.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years">Bachelor of Laws (LLB) 4 years</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bachelor-of-laws-llb-4-years"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-business-analytics">
#  <img alt="BS Business Analytics" src="https://www.mul.edu.pk/images/programs/bs-business-analytics_492.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-business-analytics">BS Business Analytics</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-business-analytics"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-psychology">
#  <img alt="BS Psychology" src="https://www.mul.edu.pk/images/programs/bs-psychology_507.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-psychology">BS Psychology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-psychology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology">
#  <img alt="BS Aesthetics and Cosmetology" src="https://www.mul.edu.pk/images/programs/bs-aesthetics-and-cosmetology_515.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology">BS Aesthetics and Cosmetology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-aesthetics-and-cosmetology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-computer-science">
#  <img alt="BS Computer Science" src="https://www.mul.edu.pk/images/programs/bs-computer-science_1.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-computer-science">BS Computer Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-computer-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy">
#  <img alt="Doctor of Pharmacy" src="https://www.mul.edu.pk/images/programs/doctor-of-pharmacy_256.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 5 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy">Doctor of Pharmacy</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/doctor-of-pharmacy"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-information-technology">
#  <img alt="BS Information Technology" src="https://www.mul.edu.pk/images/programs/bs-information-technology_2.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-information-technology">BS Information Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-information-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-software-engineering">
#  <img alt="BS Software Engineering" src="https://www.mul.edu.pk/images/programs/bs-software-engineering_9.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-software-engineering">BS Software Engineering</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-software-engineering"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence">
#  <img alt="BS Artificial Intelligence" src="https://www.mul.edu.pk/images/programs/bs-artificial-intelligence_240.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence">BS Artificial Intelligence</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-artificial-intelligence"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-cyber-security">
#  <img alt="BS Cyber Security" src="https://www.mul.edu.pk/images/programs/bs-cyber-security_241.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-cyber-security">BS Cyber Security</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-cyber-security"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bba">
#  <img alt="BBA" src="https://www.mul.edu.pk/images/programs/bba_4.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bba">BBA</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bba"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-education">
#  <img alt="BS Education" src="https://www.mul.edu.pk/images/programs/bs-education_155.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-education">BS Education</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-education"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-biotechnology">
#  <img alt="BS Biotechnology" src="https://www.mul.edu.pk/images/programs/bs-biotechnology_243.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-biotechnology">BS Biotechnology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-biotechnology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-data-science">
#  <img alt="BS Data Science" src="https://www.mul.edu.pk/images/programs/bs-data-science_292.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-data-science">BS Data Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-data-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-english">
#  <img alt="BS English" src="https://www.mul.edu.pk/images/programs/bs_10.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-english">BS English</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-english"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-political-science">
#  <img alt="BS Political Science" src="https://www.mul.edu.pk/images/programs/bs-political-science_13.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-political-science">BS Political Science</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-political-science"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-international-relations">
#  <img alt="BS International Relations" src="https://www.mul.edu.pk/images/programs/bs-international-relations_14.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-international-relations">BS International Relations</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-international-relations"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology">
#  <img alt="BS Medical Laboratory Technology" src="https://www.mul.edu.pk/images/programs/bs-medical-laboratory-technology_24.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology">BS Medical Laboratory Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-medical-laboratory-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-food-science-technology">
#  <img alt="BS Food Science &amp; Technology" src="https://www.mul.edu.pk/images/programs/bs-food-science-technology_166.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-food-science-technology">BS Food Science &amp; Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-food-science-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-economics">
#  <img alt="BS Economics" src="https://www.mul.edu.pk/images/programs/bs-economics_64.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-economics">BS Economics</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology">
#  <img alt="BS Economics and Financial Technology" src="https://www.mul.edu.pk/images/programs/bs-economics-and-financial-technology_66.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology">BS Economics and Financial Technology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-economics-and-financial-technology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance">
#  <img alt="BS Islamic Banking &amp; Finance" src="https://www.mul.edu.pk/images/programs/bs-islamic-banking-finance_71.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance">BS Islamic Banking &amp; Finance</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-islamic-banking-amp-finance"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bcom-4-year">
#  <img alt="B.Com (4 Year)" src="https://www.mul.edu.pk/images/programs/bcom-4-year_92.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bcom-4-year">B.Com (4 Year)</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bcom-4-year"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance">
#  <img alt="BS Accounting and Finance" src="https://www.mul.edu.pk/images/programs/bs-accounting-and-finance_93.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance">BS Accounting and Finance</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-accounting-and-finance"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-sociology">
#  <img alt="BS Sociology" src="https://www.mul.edu.pk/images/programs/bs-sociology_121.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-sociology">BS Sociology</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-sociology"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering">
#  <img alt="B.Sc. Chemical Engineering" src="https://www.mul.edu.pk/images/programs/bsc-chemical-engineering_130.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering">B.Sc. Chemical Engineering</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bsc-chemical-engineering"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering">
#  <img alt="B.Sc. Electrical Engineering" src="https://www.mul.edu.pk/images/programs/bsc-electrical-engineering_135.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering">B.Sc. Electrical Engineering</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bsc-electrical-engineering"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-biochemistry">
#  <img alt="BS Biochemistry" src="https://www.mul.edu.pk/images/programs/bs-biochemistry_172.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-biochemistry">BS Biochemistry</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-biochemistry"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="maso-item cat--3 col-lg-4 mb--40">
#  <div class="rbt-card variation-01 rbt-hover">
#  <div class="rbt-card-img">
#  <a href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies">
#  <img alt="BS Peace and Conflict Studies" src="https://www.mul.edu.pk/images/programs/bs-peace-and-conflict-studies_180.jpg"/>
#  </a>
#  </div>
#  <div class="rbt-card-body">
#  <div class="rbt-card-top">
#  <div class="rbt-review">
#  <span class="rating-count"><i class="feather-book"></i> 4 Years</span>
#  </div>
#  </div>
#  <h4 class="rbt-card-title"><a href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies">BS Peace and Conflict Studies</a></h4>
#  <div class="rbt-card-bottom">
#  <a class="rbt-btn-link left-icon" href="https://www.mul.edu.pk/en/program/bs-peace-and-conflict-studies"> Find Out More <i class="feather-arrow-right"></i></a>
#  <a class="rbt-btn-link left-icon" href="https://admission.mul.edu.pk/" target="_blank"> Apply Now <i class="feather-arrow-right"></i></a>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
main[0]
# Out:
# <div class="rbt-card-img">
# <a href="https://www.mul.edu.pk/en/program/bs-human-nutrition-and-dietetics">
# <img alt="BS Human Nutrition and Dietetics" src="https://www.mul.edu.pk/images/programs/bs-human-nutrition-and-dietetics_245.jpg"/>
# </a>
# </div>

# %%
web = soup.find_all("div", class_="maso-item")

# %%
name = []

for i in web:
    course_name = i.find('a').find('img')['alt']
    name.append(course_name)

print(name)
# Out:
# ['BS Human Nutrition and Dietetics', 'BS Criminology and Forensic Sciences', 'BS Digital Marketing', 'BS E-Commerce', 'BS in Digital Media Communication', 'BS in Multimedia Arts- Animation', 'Bachelor of Science in Financial Technology', 'BS Economics and Data Science', 'BS Statistics & Data Science', 'BS Computational Plant Sciences', 'BS Chemistry &  Industrial Entrepreneurship', 'BS Information System & Technology Management', ' BS Zoology and Entomology', 'BS Islamic Banking &  Financial Technology', 'BS Information Management', 'BS Mathematics & Data Science', 'BS Defense and Strategic Studies', 'Bachelor of Laws (LLB) 4 years', 'BS Business Analytics', 'BS Psychology', 'BS Aesthetics and Cosmetology', 'BS Computer Science', 'Doctor of Pharmacy', 'BS Information Technology', 'BS Software Engineering', 'BS Artificial Intelligence', 'BS Cyber Security', 'BBA', 'BS Education', 'BS Biotechnology', 'BS Data Science', 'BS English', 'BS Political Science', 'BS International Relations', 'BS Medical Laboratory Technology', 'BS Food Science & Technology', 'BS Economics', 'BS Economics and Financial Technology', 'BS Islamic Banking & Finance', 'B.Com (4 Year)', 'BS Accounting and Finance', 'BS Sociology', 'B.Sc. Chemical Engineering', 'B.Sc. Electrical Engineering', 'BS Biochemistry', 'BS Peace and Conflict Studies']

# %%
len(name)
# Out:
# 46

# %%
df = pd.DataFrame({'course_name': name})
df.tail()
# Out:
#                       course_name
# 41                   BS Sociology
# 42     B.Sc. Chemical Engineering
# 43   B.Sc. Electrical Engineering
# 44                BS Biochemistry
# 45  BS Peace and Conflict Studies

# %%
links = []

for i in web:
    course_link = i.find('a')['href']
    links.append(course_link)

# print(links)

# %%
df = pd.DataFrame({"Course_Links": links})

# %%
df
# Out:
#                                          Course_Links
# 0   https://www.mul.edu.pk/en/program/bs-human-nut...
# 1   https://www.mul.edu.pk/en/program/bs-criminolo...
# 2   https://www.mul.edu.pk/en/program/bs-digital-m...
# 3     https://www.mul.edu.pk/en/program/bs-e-commerce
# 4   https://www.mul.edu.pk/en/program/bs-in-digita...
# 5   https://www.mul.edu.pk/en/program/bs-in-multim...
# 6   https://www.mul.edu.pk/en/program/bachelor-of-...
# 7   https://www.mul.edu.pk/en/program/bs-economics...
# 8   https://www.mul.edu.pk/en/program/bs-statistic...
# 9   https://www.mul.edu.pk/en/program/bs-computati...
# 10  https://www.mul.edu.pk/en/program/bs-chemistry...
# 11  https://www.mul.edu.pk/en/program/bs-informati...
# 12  https://www.mul.edu.pk/en/program/bs-zoology-a...
# 13  https://www.mul.edu.pk/en/program/bs-islamic-b...
# 14  https://www.mul.edu.pk/en/program/bs-informati...
# 15  https://www.mul.edu.pk/en/program/bs-mathemati...
# 16  https://www.mul.edu.pk/en/program/bs-defense-a...
# 17  https://www.mul.edu.pk/en/program/bachelor-of-...
# 18  https://www.mul.edu.pk/en/program/bs-business-...
# 19    https://www.mul.edu.pk/en/program/bs-psychology
# 20  https://www.mul.edu.pk/en/program/bs-aesthetic...
# 21  https://www.mul.edu.pk/en/program/bs-computer-...
# 22  https://www.mul.edu.pk/en/program/doctor-of-ph...
# 23  https://www.mul.edu.pk/en/program/bs-informati...
# 24  https://www.mul.edu.pk/en/program/bs-software-...
# 25  https://www.mul.edu.pk/en/program/bs-artificia...
# 26  https://www.mul.edu.pk/en/program/bs-cyber-sec...
# 27              https://www.mul.edu.pk/en/program/bba
# 28     https://www.mul.edu.pk/en/program/bs-education
# 29  https://www.mul.edu.pk/en/program/bs-biotechno...
# 30  https://www.mul.edu.pk/en/program/bs-data-science
# 31       https://www.mul.edu.pk/en/program/bs-english
# 32  https://www.mul.edu.pk/en/program/bs-political...
# 33  https://www.mul.edu.pk/en/program/bs-internati...
# 34  https://www.mul.edu.pk/en/program/bs-medical-l...
# 35  https://www.mul.edu.pk/en/program/bs-food-scie...
# 36     https://www.mul.edu.pk/en/program/bs-economics
# 37  https://www.mul.edu.pk/en/program/bs-economics...
# 38  https://www.mul.edu.pk/en/program/bs-islamic-b...
# 39      https://www.mul.edu.pk/en/program/bcom-4-year
# 40  https://www.mul.edu.pk/en/program/bs-accountin...
# 41     https://www.mul.edu.pk/en/program/bs-sociology
# 42  https://www.mul.edu.pk/en/program/bsc-chemical...
# 43  https://www.mul.edu.pk/en/program/bsc-electric...
# 44  https://www.mul.edu.pk/en/program/bs-biochemistry
# 45  https://www.mul.edu.pk/en/program/bs-peace-and...
