# %% [markdown]
# # Upload dtsupply.us images to Cloudflare R2 (v3 — cloudscraper)
#
# **Fix:** even with full browser-like headers, downloads still got 403 — their CDN is behind Cloudflare-style bot/TLS-fingerprint protection that plain `requests` can't get past no matter the headers. This version uses **`cloudscraper`** instead, a library built specifically to get past this kind of protection.
#
# **Run the cell below first** to clear the partial CSV from the failed attempts, so those rows get retried properly.

# %%
import os
if os.path.exists("dtsupply_products_r2.csv"):
    os.remove("dtsupply_products_r2.csv")
    print("Old partial CSV deleted — ready for a fresh run.")
else:
    print("No existing file found — starting fresh.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 if os.path.exists("dtsupply_products_r2.csv"):
# ----> 3     os.remove("dtsupply_products_r2.csv")
#       4     print("Old partial CSV deleted — ready for a fresh run.")
#       5 else:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'dtsupply_products_r2.csv'

# %%
# !pip install requests boto3 cloudscraper
# Out:
# Requirement already satisfied: requests in c:\users\bilal\anaconda3\lib\site-packages (2.34.2)
# Requirement already satisfied: boto3 in c:\users\bilal\anaconda3\lib\site-packages (1.43.72)
# Collecting cloudscraper
#   Downloading cloudscraper-1.2.71-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\bilal\anaconda3\lib\site-packages (from requests) (2026.7.22)
# Requirement already satisfied: botocore<1.44.0,>=1.43.72 in c:\users\bilal\anaconda3\lib\site-packages (from boto3) (1.43.72)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\bilal\anaconda3\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in c:\users\bilal\anaconda3\lib\site-packages (from boto3) (0.19.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\bilal\anaconda3\lib\site-packages (from botocore<1.44.0,>=1.43.72->boto3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\bilal\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.72->boto3) (1.17.0)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\bilal\anaconda3\lib\site-packages (from cloudscraper) (3.3.2)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\bilal\anaconda3\lib\site-packages (from cloudscraper) (1.0.0)
# Downloading cloudscraper-1.2.71-py2.py3-none-any.whl (99 kB)
# Installing collected packages: cloudscraper
# Successfully installed cloudscraper-1.2.71

# %%
#!/usr/bin/env python3
"""
Takes the image URLs from dtsupply_products.csv, downloads each image
(using a Referer header so their CDN's hotlink protection doesn't block us),
uploads it to Cloudflare R2, and writes a NEW CSV with the "image" column
replaced by the new R2-hosted URL.

Requirements:
    pip install requests boto3

Output:
    dtsupply_products_r2.csv

Resumable: if you stop it and rerun, it skips products (by product_id)
already present in the output CSV.
"""

import csv
import os
import re
import time
import hashlib
from urllib.parse import urlparse

import requests
import boto3
import cloudscraper
from botocore.config import Config

# ---------------------------------------------------------------------------
# CLOUDFLARE R2 SETTINGS — reusing the same bucket/account from before
# ---------------------------------------------------------------------------
CLOUDFLARE_ACCOUNT_ID = "d42f7c5ed83f1403699b96fc13759c01"
R2_ACCESS_KEY_ID = "93510dc42d0c272e24a95c87f7a20313"
R2_SECRET_ACCESS_KEY = "38de75f0cdb543d0e6f81811faab924e31ec6116cc95edb5d6e5e094a7b11241"
R2_BUCKET_NAME = "syntexserver-2003"
R2_PUBLIC_URL_BASE = "https://pub-4ae70fe1d6cf4e5ea327e14b66c0ad8e.r2.dev"

# ---------------------------------------------------------------------------
INPUT_CSV = "dtsupply_products.csv"
OUTPUT_CSV = "dtsupply_products_r2.csv"
REQUEST_DELAY = 0.3
TIMEOUT = 20
PROGRESS_EVERY = 25
KEY_PREFIX = "dtsupply-products/"   # separate folder inside the bucket, keeps these apart from the vertexnetworking images

CONTENT_TYPES = {
    ".jpg": "image/jpeg", ".jpeg": "image/jpeg",
    ".png": "image/png", ".webp": "image/webp",
    ".gif": "image/gif", ".bmp": "image/bmp",
}

session = cloudscraper.create_scraper(
    browser={"browser": "chrome", "platform": "windows", "mobile": False}
)
session.headers.update({
    # Their CDN blocks hotlinking unless the request looks like it came
    # from the dtsupply.us site itself. Plain requests + these headers
    # alone weren't enough (still got 403), so this uses cloudscraper
    # instead of plain requests — it handles Cloudflare-style bot/TLS
    # fingerprint checks that a normal requests.Session can't get past.
    "Referer": "https://dtsupply.us/",
    "Origin": "https://dtsupply.us",
    "Accept": "image/avif,image/webp,image/apng,image/svg+xml,image/*,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.9",
    "Sec-Fetch-Dest": "image",
    "Sec-Fetch-Mode": "no-cors",
    "Sec-Fetch-Site": "cross-site",
})

s3 = boto3.client(
    "s3",
    endpoint_url=f"https://{CLOUDFLARE_ACCOUNT_ID}.r2.cloudflarestorage.com",
    aws_access_key_id=R2_ACCESS_KEY_ID,
    aws_secret_access_key=R2_SECRET_ACCESS_KEY,
    config=Config(signature_version="s3v4"),
    region_name="auto",
)


def safe_filename(url, sku=""):
    parsed = urlparse(url)
    ext = os.path.splitext(parsed.path)[1].lower()
    if ext not in CONTENT_TYPES:
        ext = ".jpg"
    base = (sku or "").strip()
    if not base:
        base = hashlib.md5(url.encode("utf-8")).hexdigest()[:12]
    base = re.sub(r"[^A-Za-z0-9_\-]", "_", base)
    return f"{base}{ext}"


def download_image(url):
    try:
        resp = session.get(url, timeout=TIMEOUT)
        resp.raise_for_status()
        return resp.content
    except requests.RequestException as e:
        print(f"  [warn] failed to download {url}: {e}")
        return None


def upload_to_r2(content, key, content_type):
    try:
        s3.put_object(
            Bucket=R2_BUCKET_NAME,
            Key=key,
            Body=content,
            ContentType=content_type,
        )
        return f"{R2_PUBLIC_URL_BASE.rstrip('/')}/{key}"
    except Exception as e:
        print(f"  [warn] failed to upload {key} to R2: {e}")
        return None


def load_already_done():
    done = set()
    if os.path.exists(OUTPUT_CSV):
        with open(OUTPUT_CSV, "r", newline="", encoding="utf-8") as f:
            reader = csv.DictReader(f)
            for row in reader:
                pid = row.get("product_id")
                image = (row.get("image") or "").strip()
                if pid and (not image or image.startswith(R2_PUBLIC_URL_BASE)):
                    done.add(str(pid))
    return done


def main():
    if not os.path.exists(INPUT_CSV):
        raise SystemExit(f"Can't find {INPUT_CSV} — put this notebook in the same folder.")

    already_done = load_already_done()
    if already_done:
        print(f"Resuming — {len(already_done)} products already done in {OUTPUT_CSV}, will skip those.")

    with open(INPUT_CSV, "r", newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        fieldnames = reader.fieldnames
        rows = list(reader)

    total = len(rows)
    print(f"Loaded {total} rows from {INPUT_CSV}.")

    file_exists = os.path.exists(OUTPUT_CSV)
    out_f = open(OUTPUT_CSV, "a", newline="", encoding="utf-8")
    writer = csv.DictWriter(out_f, fieldnames=fieldnames)
    if not file_exists:
        writer.writeheader()
        out_f.flush()

    processed = len(already_done)

    try:
        for row in rows:
            product_id = str(row.get("product_id", ""))
            if product_id and product_id in already_done:
                continue

            new_row = dict(row)
            image_url = (row.get("image") or "").strip()

            if image_url:
                content = download_image(image_url)
                if content:
                    ext = os.path.splitext(urlparse(image_url).path)[1].lower()
                    content_type = CONTENT_TYPES.get(ext, "image/jpeg")
                    key = KEY_PREFIX + safe_filename(image_url, row.get("sku", ""))
                    new_url = upload_to_r2(content, key, content_type)
                    if new_url:
                        new_row["image"] = new_url
                    time.sleep(REQUEST_DELAY)

            writer.writerow(new_row)
            out_f.flush()
            processed += 1

            if processed % PROGRESS_EVERY == 0:
                print(f"  >>> progress: {processed}/{total} rows processed")

    except KeyboardInterrupt:
        print("\n[stopped by user] Progress so far is safely saved.")
    finally:
        out_f.close()

    print(f"\nDone. {processed}/{total} rows written to {OUTPUT_CSV}")
    print("(rerun this cell anytime to resume/finish remaining rows)")


if __name__ == "__main__":
    main()
# Out:
# Resuming — 103 products already done in dtsupply_products_r2.csv, will skip those.
# Loaded 231685 rows from dtsupply_products.csv.
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/00XL284.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/00XL284.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/017PW.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/017PW.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/056397-000.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/056397-000.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/0DKY0.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/0DKY0.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/0G017A.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/0G017A.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/0WV2P.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/0WV2P.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/0YYM2.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/0YYM2.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/174922-003.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/174922-003.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/181UR.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/181UR.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/2201-61063-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/2201-61063-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/250-0094-01.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/250-0094-01.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/2FGX8.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/2FGX8.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/2MCFR.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/2MCFR.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/2RJ7P.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/2RJ7P.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/36832-41.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/36832-41.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/385980-003.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/385980-003.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/3KJ1T.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/3KJ1T.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/3P11H.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/3P11H.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/3WTMD.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/3WTMD.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/440920-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/440920-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/443909-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/443909-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/4TYFR.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/4TYFR.webp
#   >>> progress: 125/231685 rows processed
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/540-2072.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/540-2072.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/583283-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/583283-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/5M40S38055.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/5M40S38055.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/5SB0S73516.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/5SB0S73516.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/60PC4.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/60PC4.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/640449-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/640449-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/642798-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/642798-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/644320-005.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/644320-005.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/686695-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/686695-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/68KKR.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/68KKR.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/6X34R.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/6X34R.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/702FF.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/702FF.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/716048-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/716048-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/799107-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/799107-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/7K0CH.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/7K0CH.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/7W073AA#ABA.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/7W073AA#ABA.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/8VKRK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/8VKRK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/924343-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/924343-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/924935-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/924935-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/925445-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/925445-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/92F1319.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/92F1319.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/9559-583-125.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/9559-583-125.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BA96-07675A.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BA96-07675A.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT008-BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT008-BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT008-RED.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT008-RED.webp
#   >>> progress: 150/231685 rows processed
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT009-BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT009-BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT012-BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT012-BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT012-PINK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT012-PINK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT012-SILVER.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT012-SILVER.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT014-BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT014-BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/BT014-WHITE.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/BT014-WHITE.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/C054A.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/C054A.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/CH8TH.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/CH8TH.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/CN7FW.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/CN7FW.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/G4NDK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/G4NDK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/G9035.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/G9035.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/GS550.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/GS550.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/H21BK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/H21BK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/H21WHITE.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/H21WHITE.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/H510 BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/H510%20BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/HW251N.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/HW251N.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/J1XV6.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/J1XV6.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/L20453-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/L20453-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/L28271-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/L28271-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/L44513-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/L44513-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/L73318-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/L73318-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/M07208-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/M07208-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/M07209-001.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/M07209-001.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/MD212RED.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/MD212RED.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/MD212WHITE.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/MD212WHITE.webp
#   >>> progress: 175/231685 rows processed
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/MFX68.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/MFX68.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/MKD1J.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/MKD1J.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/MM8P6.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/MM8P6.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/NY6W3.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/NY6W3.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/P07CN.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/P07CN.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/PEXSOUND7CH.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/PEXSOUND7CH.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/PX3DR.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/PX3DR.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/QY-BG002 D107726.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/QY-BG002%20D107726.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/QY-BG002 D109890.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/QY-BG002%20D109890.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/R6JWX.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/R6JWX.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/S630 BLACK.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/S630%20BLACK.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/SB0220.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/SB0220.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/SP-DE126.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/SP-DE126.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/T11.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/T11.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/T22.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/T22.webp
#   [warn] failed to download https://cdn.cmshardware.com/images/Images/Products/TX47W.webp: 403 Client Error: Forbidden for url: https://cdn.cmshardware.com/images/Images/Products/TX47W.webp
