# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples=6, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([49.27984143])

# %%
reg.intercept_
# Out:
# np.float64(4.202221374439645)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')

# %%
m = 49.27
b = 50

y_pred = ((48.53*x) + b).reshape(6)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')
plt.plot(x,y_pred, color='green', label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum (y - 49.27*x.ravel() - b)
loss_slope
# Out:
# np.float64(549.5275587062449)

# %%
lr = 0.10

step_size = lr * loss_slope
step_size
# Out:
# np.float64(54.95275587062449)

# %%
b = b - step_size
b
# Out:
# np.float64(-4.952755870624493)

# %%
y_pred1 = ((49.27*x) + b).reshape(6)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')
plt.plot(x,y_pred1, color='purple', label='b = {}'.format(b))
plt.plot(x,y_pred, color='green', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 49.27*x.ravel() - b)
loss_slope
# Out:
# np.float64(-109.90551174124893)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(-10.990551174124894)

# %%
b = b - step_size
b
# Out:
# np.float64(6.037795303500401)

# %%
y_pred2 = ((48.53*x) + b).reshape(6)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red', label = 'OSL')
plt.plot(x,y_pred2, color='yellow', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 49.27*x.ravel() - b)
loss_slope
# Out:
# np.float64(21.981102348249806)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(2.1981102348249806)

# %%
b = b - step_size
b
# Out:
# np.float64(3.8396850686754203)

# %%
y_pred3 = ((48.53*x) + b).reshape(6)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red', label = 'OSL')
plt.plot(x,y_pred3, color='orange', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 49.27*x.ravel() - b)
loss_slope
# Out:
# np.float64(0.8792440939300121)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(0.08792440939300122)

# %%
b = b - step_size
b
# Out:
# np.float64(4.191382706247415)

# %%
y_pred4 = ((49.27*x) + b).reshape(6)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red', label = 'OSL')
plt.plot(x,y_pred4, color='orange', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 49.27*x.ravel() - b)
loss_slope
# Out:
# np.float64(-0.17584881878603653)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(-0.017584881878603655)

# %%
b = b - step_size
b
# Out:
# np.float64(4.2089675881260185)

# %%
y_pred5 = ((49.27*x) + b).reshape(6)
