# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
x,y = make_regression(n_samples=10, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([48.53048884])

# %%
reg.intercept_
# Out:
# np.float64(-18.451671098764226)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')

# %%
m = 48.53
b = 100

y_pred = ((48.53*x) + b).reshape(10)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')
plt.plot(x,y_pred, color='green', label='b = {}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope = -2 * np.sum (y - 48.53*x.ravel() - b)
loss_slope
# Out:
# np.float64(2369.028562119997)

# %%
lr = 0.10

step_size = lr * loss_slope
step_size
# Out:
# np.float64(236.9028562119997)

# %%
b = b - step_size
b
# Out:
# np.float64(-136.9028562119997)

# %%
y_pred1 = ((48.53*x) + b).reshape(10)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red')
plt.plot(x,y_pred1, color='purple', label='b = {}'.format(b))
plt.plot(x,y_pred, color='green', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 48.53*x.ravel() - b)
loss_slope
# Out:
# np.float64(-2369.028562119997)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(-236.9028562119997)

# %%
b = b - step_size
b
# Out:
# np.float64(100.0)

# %%
y_pred2 = ((48.53*x) + b).reshape(10)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red', label = 'OSL')
plt.plot(x,y_pred2, color='yellow', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
loss_slope = -2 * np.sum (y - 48.53*x.ravel() - b)
loss_slope
# Out:
# np.float64(2369.028562119997)

# %%
step_size = lr * loss_slope
step_size
# Out:
# np.float64(236.9028562119997)

# %%
b = b - step_size
b
# Out:
# np.float64(-136.9028562119997)

# %%
y_pred3 = ((48.53*x) + b).reshape(10)

# %%
plt.scatter(x,y)
plt.plot(x, reg.predict(x), color='red', label = 'OSL')
plt.plot(x,y_pred3, color='orange', label='b = {}'.format(b))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
