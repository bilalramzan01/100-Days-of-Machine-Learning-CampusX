# %% [markdown]
# ### What Is Stochastic Gradient Descent (SGD)?
#
# Stochastic Gradient Descent updates the parameters using just ONE random data point at a time, instead of the entire dataset like Batch GD does. "Stochastic" means "random" — you randomly pick one row, compute the gradient from it alone, and immediately update m and b.
